# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
from pprint_utf import pprint
import re
from collections import defaultdict
import csv
import codecs

# %% [markdown]
# ### 获取探索样本

# %%
OSM_FILE = "beijing_china.osm"
SAMPLE_FILE = "sample.osm"

k = 10 # Parameter: taken every k-th top level element

def get_element(osm_file, tags = ("node", "way", "relation")):
    """Yield element if it is the right type of tag"""
    context = iter(ET.iterparse(osm_file, events = ('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()
            
with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')
    
    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding = 'utf-8'))
            
    output.write('</osm>')

# %% [markdown]
# ### 对探索样本中部分字段数据质量进行审查

# %%
# 审查函数
def audit(osm_file, k_value):
    to_be_audited = {k_value: set()}
    for event, elem in ET.iterparse(osm_file, events = ('start',)):
        if elem.tag == 'way' or elem.tag == 'node':
            for tag in elem.iter('tag'):
                if tag.attrib['k'] == k_value:
                    to_be_audited[k_value].add(tag.attrib['v'])
    pprint(to_be_audited)

# %%
# 查看‘tag’标签中所有'k'的值并计数，从而方便进行审查
tag_name = {}
for _, elem in ET.iterparse(SAMPLE_FILE):
    for tag in elem.iter('tag'):
        if tag.attrib['k'] not in tag_name:
            tag_name[tag.attrib['k']] = 1
        else:
            tag_name[tag.attrib['k']] += 1
pprint(sorted(tag_name.iteritems(), key = lambda d:d[1], reverse = True))
# Out:
# [('highway', 23535),
#  ('building', 15081),
#  ('name', 12168),
#  ('oneway', 6339),
#  ('power', 4290),
#  ('public_transport', 3528),
#  ('source', 2985),
#  ('name:en', 2826),
#  ('railway', 2451),
#  ('ref', 2436),
#  ('bridge', 2394),
#  ('layer', 2364),
#  ('amenity', 2184),
#  ('type', 1719),
#  ('lanes', 1569),
#  ('name:zh', 1344),
#  ('shelter', 1191),
#  ('bench', 1134),
#  ('service', 1125),
#  ('building:levels', 1068),
#  ('landuse', 924),
#  ('barrier', 903),
#  ('gauge', 789),
#  ('leisure', 651),
#  ('electrified', 603),
#  ('natural', 591),
#  ('voltage', 588),
#  ('shop', 558),
#  ('name:zh_pinyin', 543),
#  ('to', 522),
#  ('from', 522),
#  ('route', 510),
#  ('tourism', 477),
#  ('frequency', 441),
#  ('surface', 441),
#  ('int_name', 435),
#  ('access', 405),
#  ('operator', 393),
#  ('tunnel', 390),
#  ('addr:housenumber', 366),
#  ('aeroway', 345),
#  ('crossing', 342),
#  ('man_made', 321),
#  ('addr:street', 318),
#  ('waterway', 312),
#  ('network', 261),
#  ('route_master', 237),
#  ('alt_name', 234),
#  ('int_ref', 225),
#  ('maxheight', 225),
#  ('subway', 216),
#  ('sport', 216),
#  ('cuisine', 207),
#  ('foot', 201),
#  ('FIXME', 195),
#  ('addr:city', 183),
#  ('place', 180),
#  ('name:de', 174),
#  ('short_name', 171),
#  ('created_by', 165),
#  ('roof:shape', 165),
#  ('height', 162),
#  ('name:fr', 150),
#  ('area', 144),
#  ('bicycle', 141),
#  ('covered', 141),
#  ('historic', 141),
#  ('exit_to', 138),
#  ('note', 135),
#  ('website', 135),
#  ('restriction', 129),
#  ('roof:colour', 123),
#  ('maxspeed', 114),
#  ('addr:postcode', 114),
#  ('opening_hours', 111),
#  ('traffic_signals', 111),
#  ('usage', 108),
#  ('cycleway:right', 105),
#  ('colour', 99),
#  ('cycleway', 96),
#  ('name:ru', 93),
#  ('trolley_wire', 93),
#  ('office', 90),
#  ('roof:material', 87),
#  ('alt_name:en', 84),
#  ('static', 81),
#  ('junction', 81),
#  ('parking', 81),
#  ('lit', 81),
#  ('level', 75),
#  ('passenger_lines', 75),
#  ('cables', 69),
#  ('internet_access', 66),
#  ('disused', 60),
#  ('phone', 60),
#  ('two_sided', 60),
#  ('toll', 60),
#  ('smoking', 57),
#  ('wheelchair', 54),
#  ('wikipedia', 54),
#  ('viewColor', 54),
#  ('motor_vehicle', 51),
#  ('addr:full', 51),
#  ('footway', 51),
#  ('brand', 51),
#  ('hour_off', 48),
#  ('hour_on', 48),
#  ('payment:telephone_cards', 45),
#  ('wikidata', 45),
#  ('horse', 42),
#  ('converted_by', 42),
#  ('payment:electronic_purses', 39),
#  ('width', 39),
#  ('admin_level', 39),
#  ('boundary', 36),
#  ('disused:route', 36),
#  ('source:name', 33),
#  ('name:ja', 33),
#  ('construction', 33),
#  ('water', 30),
#  ('capacity', 30),
#  ('building:colour', 30),
#  ('tracks', 30),
#  ('boat', 30),
#  ('fee', 27),
#  ('description', 27),
#  ('diplomatic', 27),
#  ('building:material', 27),
#  ('entrance', 24),
#  ('takeaway', 24),
#  ('addr:housename', 24),
#  ('historic:civilization', 24),
#  ('code', 21),
#  ('indoor', 21),
#  ('atm', 21),
#  ('sac_scale', 21),
#  ('station', 21),
#  ('building:part', 21),
#  ('country', 21),
#  ('psv', 21),
#  ('highspeed', 21),
#  ('buildingpart', 18),
#  ('alt_name:zh_pinyin', 18),
#  ('name:pl', 18),
#  ('fixme', 18),
#  ('loc_name', 18),
#  ('addr:district', 18),
#  ('internet_access:fee', 18),
#  ('name:es', 18),
#  ('name:vi', 18),
#  ('name:it', 15),
#  ('military', 15),
#  ('outdoor_seating', 15),
#  ('name:th', 15),
#  ('maxweight', 15),
#  ('roof:height', 15),
#  ('tracktype', 15),
#  ('ramp', 15),
#  ('ele', 15),
#  ('except', 15),
#  ('delivery', 15),
#  ('short_name:zh', 12),
#  ('name:pt', 12),
#  ('tower:type', 12),
#  ('history', 12),
#  ('gns:UFI', 12),
#  ('motorcycle', 12),
#  ('source:position', 12),
#  ('designation', 12),
#  ('generator:source', 12),
#  ('motorcar', 12),
#  ('nsdi_code', 12),
#  ('target', 12),
#  ('gns:UNI', 12),
#  ('gns:DSG', 12),
#  ('route_ref', 12),
#  ('short_name:en', 12),
#  ('addr:province', 12),
#  ('gns:ADM1', 12),
#  ('heritage', 12),
#  ('circuits', 12),
#  ('wifi', 12),
#  ('heritage:operator', 12),
#  ('ref:cn:guobao', 9),
#  ('cycleway:left', 9),
#  ('embankment', 9),
#  ('name:sk', 9),
#  ('name:sv', 9),
#  ('name:hu', 9),
#  ('disused:railway', 9),
#  ('name:ko', 9),
#  ('zhb_code', 9),
#  ('email', 9),
#  ('maxaxleload', 9),
#  ('addr:country', 9),
#  ('name:cs', 9),
#  ('emergency', 9),
#  ('religion', 9),
#  ('old_name', 9),
#  ('line', 9),
#  ('area:highway', 6),
#  ('wikipedia:en', 6),
#  ('railway:traffic_mode', 6),
#  ('disused:highway', 6),
#  ('visibility', 6),
#  ('loc_name:en', 6),
#  ('segregated', 6),
#  ('oneway:hour_off', 6),
#  ('ref:whc', 6),
#  ('disused:public_transport', 6),
#  ('aerialway', 6),
#  ('population', 6),
#  ('restriction:tourist_bus', 6),
#  ('name:zh-simplified', 6),
#  ('healthcare', 6),
#  ('name:lv', 6),
#  ('name:Pinyin', 6),
#  ('bicycle_parking', 6),
#  ('loc_name:zh', 6),
#  ('disused:route_master', 6),
#  ('gns:dsg', 6),
#  ('hgv', 6),
#  ('name:ca', 6),
#  ('loc_name:zh_pinyin', 6),
#  ('artwork_type', 6),
#  ('name:zh-traditional', 6),
#  ('loc_name:fr', 6),
#  ('supervised', 6),
#  ('contact:website', 6),
#  ('contact:phone', 6),
#  ('oneway:hour_on', 6),
#  ('bus', 6),
#  ('bridge:name:en', 6),
#  ('overwrite', 6),
#  ('name:nl', 6),
#  ('time', 6),
#  ('restriction:hgv', 6),
#  ('building:height', 3),
#  ('name:bat-smg', 3),
#  ('ref:en', 3),
#  ('fax', 3),
#  ('name:uz', 3),
#  ('name:ur', 3),
#  ('tiger:county', 3),
#  ('name:uk', 3),
#  ('name:ug', 3),
#  ('is_in:continent', 3),
#  ('name:ilo', 3),
#  ('sidewalk', 3),
#  ('cmt', 3),
#  ('name:ia', 3),
#  ('name:lez', 3),
#  ('name:id', 3),
#  ('name:io', 3),
#  ('name:is', 3),
#  ('name:si', 3),
#  ('piste:type', 3),
#  ('name:nrm', 3),
#  ('capital', 3),
#  (u'疏散人数', 3),
#  ('access:conditional', 3),
#  ('name:br', 3),
#  ('name:roa-rup', 3),
#  ('name:bn', 3),
#  ('name:bo', 3),
#  ('name:bjn', 3),
#  ('name:be', 3),
#  ('name:bg', 3),
#  ('name:ba', 3),
#  ('colour:back', 3),
#  ('name:bcl', 3),
#  ('name:crh', 3),
#  ('name:ps', 3),
#  ('turn:lanes', 3),
#  ('alt_name:eo', 3),
#  ('color', 3),
#  ('name:pa', 3),
#  ('diet:vegetarian', 3),
#  ('name:cdo', 3),
#  ('name:rue', 3),
#  ('name:sco', 3),
#  ('name:scn', 3),
#  ('train', 3),
#  ('uic_ref', 3),
#  ('roof', 3),
#  ('alt_name:is', 3),
#  ('name:pnb', 3),
#  ('name:be-tarask', 3),
#  ('male', 3),
#  ('name:ms', 3),
#  ('name:mr', 3),
#  ('attribute', 3),
#  ('name:my', 3),
#  ('building:min_level', 3),
#  ('name:mg', 3),
#  ('access:hour_on', 3),
#  ('name:ml', 3),
#  ('name:mn', 3),
#  ('name:mi', 3),
#  ('name:mk', 3),
#  ('information', 3),
#  ('name:fi', 3),
#  ('alt_name:de', 3),
#  ('length', 3),
#  ('name:hif', 3),
#  ('name:fo', 3),
#  ('iata', 3),
#  ('name:fa', 3),
#  ('collection', 3),
#  ('name:ceb', 3),
#  ('benyes', 3),
#  ('name:tr', 3),
#  ('name:tt', 3),
#  ('name:tk', 3),
#  ('name:pdc', 3),
#  ('name:tl', 3),
#  ('name:ta', 3),
#  ('name:tg', 3),
#  ('name:te', 3),
#  ('name:pms', 3),
#  ('image', 3),
#  ('piste:difficulty', 3),
#  ('conveying', 3),
#  ('cutting', 3),
#  ('smoothness', 3),
#  ('bridge:structure', 3),
#  ('name:ay', 3),
#  ('name:az', 3),
#  ('ref:vi', 3),
#  ('name:gan', 3),
#  ('name:ar', 3),
#  ('shop_1', 3),
#  ('alt_name:zh', 3),
#  ('name:an', 3),
#  ('name:cbk-zam', 3),
#  ('name:af', 3),
#  ('house', 3),
#  ('alt_name:cs', 3),
#  ('name:za', 3),
#  ('name:so', 3),
#  ('name:sl', 3),
#  ('name:war', 3),
#  ('name:sc', 3),
#  ('name:sa', 3),
#  ('name:arz', 3),
#  ('name:sw', 3),
#  ('name:su', 3),
#  ('name:sr', 3),
#  ('name:sq', 3),
#  ('noexit', 3),
#  ('organic', 3),
#  ('name:xmf', 3),
#  ('name:tpi', 3),
#  ('rank', 3),
#  ('name:botanical', 3),
#  ('name:hi', 3),
#  ('name:he', 3),
#  ('name:bpy', 3),
#  ('name:hy', 3),
#  ('name:ht', 3),
#  ('name:hr', 3),
#  ('name:srn', 3),
#  ('name:szl', 3),
#  ('name:lmo', 3),
#  ('addr:suburb', 3),
#  ('generator:method', 3),
#  ('escalator', 3),
#  ('name:haw', 3),
#  ('piste:grooming', 3),
#  ('name:hak', 3),
#  ('name:roa-tara', 3),
#  ('disused:amenity', 3),
#  ('name:xal', 3),
#  ('alt_name:fr', 3),
#  ('name:ang', 3),
#  ('is_in:iso_3166_2', 3),
#  ('short_name:cs', 3),
#  ('name:ka', 3),
#  ('name:kn', 3),
#  ('name:km', 3),
#  ('name:kl', 3),
#  ('name:kk', 3),
#  ('name:kw', 3),
#  ('name:kv', 3),
#  ('name:ku', 3),
#  ('trail_visibility', 3),
#  ('name:frp', 3),
#  ('name:lt', 3),
#  ('name:la', 3),
#  ('roundabout', 3),
#  ('name:lo', 3),
#  ('name:el', 3),
#  ('name:eo', 3),
#  ('payment:cash', 3),
#  ('payment:credit_cards', 3),
#  ('name:lij', 3),
#  ('name:eu', 3),
#  ('name:et', 3),
#  ('name:ro', 3),
#  ('name:ckb', 3),
#  ('name:ast', 3),
#  ('old_name:ku', 3),
#  ('fuel:diesel', 3),
#  ('generator:output:electricity', 3),
#  ('attribute2', 3),
#  ('blocked', 3),
#  ('building:max_level', 3),
#  ('contact:email', 3),
#  ('key', 3),
#  ('name:sah', 3),
#  ('drive_through', 3),
#  ('name:oc', 3),
#  ('name:os', 3),
#  ('x-railway', 3),
#  ('drive_in', 3),
#  ('craft', 3),
#  ('shape:color', 3),
#  ('access:hour_off', 3),
#  ('runway', 3),
#  ('name:yi', 3),
#  ('name:yo', 3),
#  ('name:ext', 3),
#  ('fuel:octane_92', 3),
#  ('wires', 3),
#  ('fence_type', 3),
#  ('intermittent', 3),
#  ('name:wuu', 3),
#  ('name:mwl', 3),
#  ('name:cy', 3),
#  ('name:cv', 3),
#  ('oneway:psv', 3),
#  ('via', 3),
#  ('name:kab', 3),
#  ('name:da', 3),
#  ('name:dv', 3),
#  ('bridge_name', 3),
#  ('roof:orientation', 3),
#  ('amenity_1', 3),
#  ('name:nah', 3),
#  ('opening_date', 3),
#  ('name:zh-yue', 3),
#  ('name:jv', 3),
#  ('alt_name:sv', 3),
#  ('name:jbo', 3),
#  ('wikipedia:fr', 3),
#  ('name:mzn', 3),
#  ('internet_access:ssid', 3),
#  ('female', 3),
#  ('name:zh-min-nan', 3),
#  ('china_class', 3),
#  ('name:mhr', 3),
#  ('name:nov', 3),
#  ('name:pap', 3),
#  ('name:zh-classical', 3),
#  ('name:pam', 3),
#  ('name:qu', 3),
#  ('name:am', 3),
#  ('is_in:country', 3),
#  ('old_name:vi', 3),
#  ('fire_hydrant:type', 3),
#  ('oneway:bus', 3),
#  ('name:nn', 3),
#  ('name:no', 3),
#  ('name:na', 3),
#  ('is_in:country_code', 3),
#  ('name:ne', 3),
#  ('min_height', 3),
#  ('name:ga', 3),
#  ('name:gd', 3),
#  ('name:gn', 3),
#  ('name:gl', 3),
#  ('name:gv', 3),
#  ('name:gu', 3)]

# %%
# 审查'name:en'字段
audit(SAMPLE_FILE, "name:en")
# Out:
# {'name:en': set(['2nd Zhenwumiao Road',
#                  '5th Ring road',
#                  '60 Bar',
#                  '6th Ring Road',
#                  '7 Days Inn',
#                  '7-Eleven',
#                  '9th Dynasty',
#                  'ANDINGMEN DONGDAJIE',
#                  'APM',
#                  'ASIA PACIFIC GARDEN HOTEL',
#                  'Aimin Str',
#                  'Airport shuttle shangdi stop',
#                  'Alley cafe',
#                  'American animals',
#                  'An Li road',
#                  'An Ning Zhuang Road',
#                  'An Ning Zhuang West Road',
#                  'Anding Lu',
#                  'Andingmenwai Street',
#                  'Anhuaqiao',
#                  'Animal Sacrifice Pavilion',
#                  'Anxiang North Road',
#                  'Anyuanli Community',
#                  'Anzhen Road',
#                  'Aroma Zen Tea Club',
#                  'Auspicious Phoenix',
#                  'BJDW',
#                  'Ba Da Chu Road',
#                  'Ba Gou Road',
#                  'Ba River',
#                  'Babukou Alley',
#                  'Bagou',
#                  'Baima road',
#                  'Baishiqiao South',
#                  'Baiwanzhuang Str',
#                  'Baiziwan Road',
#                  'Bajiao Amusement Park',
#                  'Balizhuang Bridge',
#                  'Bao Yuan Dumpling Restaurant',
#                  'Basketball Courts',
#                  'Basketball Fields at NCEPU',
#                  'Baxian Zhuangcun',
#                  'Bei Qing Road',
#                  'BeiDong Flower Market',
#                  'Beichen West Road',
#                  'Beichizi Avenue',
#                  'Beida Huacun',
#                  'Beigangzi',
#                  'Beijing',
#                  'Beijing Chaoyang Theater',
#                  'Beijing Foreign Studies University',
#                  'Beijing Garden Expo Park',
#                  'Beijing Human Resources & Social Security Bureau',
#                  'Beijing Nanyuan Airport',
#                  'Beijing National Hospital',
#                  'Beijing No.4 High School',
#                  'Beijing Railway Station',
#                  'Beijing South',
#                  'Beijing Subway, Mentougou Line',
#                  'Beijing University of Civil Engineering and Architecture - Xicheng Campus',
#                  'Beijing WenJin Hotel',
#                  'Beijing West Railway Station',
#                  'Beijing Yuan Long Silk',
#                  'Beijing Zoo',
#                  'Beijing-Shanghai High Speed Rail',
#                  'Beiqingyun Lu',
#                  'Beixing Alley',
#                  'Beixinqiao',
#                  'Beiyuan Bridge',
#                  'Beiyuan road',
#                  'Berrybeans',
#                  'Binhe Middle Road',
#                  'Boundary Hebei - Tianjin',
#                  'Boxing Road',
#                  'Brotzeit',
#                  'Building 21',
#                  'Building 26',
#                  'Building 9',
#                  'Burger Counter',
#                  'Burger King',
#                  'Bus stop',
#                  'Caishi Rd.',
#                  'Cangjingguan Alley',
#                  'Cangnan Alley',
#                  'Caofang',
#                  'Carrefour',
#                  'Cathedral of the Immaculate Conception Xianwumen',
#                  'Center for Student Cultural Activities',
#                  'Chang Chun Qiao Road',
#                  'Chang Guan Building',
#                  'Changping Xishankou',
#                  'Changyang',
#                  'Changying',
#                  'Chaowai North Street',
#                  'Chaoyang Park Road',
#                  'Chaoyang Road',
#                  'Chaoyangmen',
#                  'Chaoyangmen Outer Street',
#                  'Chedaogou',
#                  'Chedaogou Bridge',
#                  'Chegongzhuang West',
#                  'Chegongzhuang West Street',
#                  'Chengfu Road',
#                  'Chengshousi',
#                  'China Art Museum',
#                  'China Aviation Museum',
#                  'China Merchants Bank',
#                  'China Printing Museum',
#                  'China Resources Building',
#                  'China University of Political Science and Law',
#                  'China University of Political Science and Law at Changping',
#                  'Chongwenmen Outer Street',
#                  'Circular Mound Altar',
#                  'Communication University of China',
#                  'CornerTower',
#                  'Cui Wei Shan',
#                  'Dachaye Hutong',
#                  'Dachengzi',
#                  'Dajiao Alley',
#                  'Daju Alley',
#                  'Dalianpo',
#                  'Dascom Building',
#                  'Dashi River',
#                  'Dashilan',
#                  'Dashiqiao Hutong',
#                  'Datun road',
#                  'Daxing Alley',
#                  'Deal',
#                  'Delice',
#                  'Department of Mathematics',
#                  'Deshengmen Inner Street',
#                  'Dexian Road',
#                  "Di'anmen West Street",
#                  'Digezhuangcun',
#                  'Dinghui Bridge',
#                  'Dining Hall',
#                  'Divine Kitchen (South)',
#                  'DongZhiMen',
#                  'Dongbai Road',
#                  'Donghuamen Night Market',
#                  'Dongsi 2nd Alley',
#                  'Dongsi 6th Alley',
#                  'Dongsishitiao',
#                  'Dongzhimen Outer Street',
#                  'Douban Alley',
#                  'Doudian',
#                  'Doufuchi Alley',
#                  'Dunkin Donuts',
#                  'E 3rd Ring Road',
#                  'E 3rd Ring Road N',
#                  'E. 3rd Ring Road',
#                  'E. Ritan',
#                  'E. Tianshuiyuan Str',
#                  'E. Xiushui Str',
#                  'East 4th Ring Road',
#                  'East Beiwa Road',
#                  'East Gate Cinema',
#                  'East Heavenly Gate',
#                  'East Majiabao Road',
#                  'East Panjiayuan Road',
#                  'East Qianmen Road',
#                  'East Wanliu Road',
#                  'East Yangfangdian Road',
#                  'Elements',
#                  'Embassy of France',
#                  'Embassy of Spain',
#                  'Embassy of Sweden',
#                  'Environmental Development Center',
#                  'Exit A',
#                  'Exit D',
#                  'Family Mart',
#                  'Fangyuan South Street',
#                  'Fangzhuang Avenue',
#                  'Fantastic dumpling restaurant',
#                  'Fasting Palace',
#                  'Fengxiang Street',
#                  'Fenzhou Hutong',
#                  'Forbidden City',
#                  'Former Dormitory Bldg',
#                  "Four Martyr's Tomb",
#                  'Friendship Palace',
#                  'Fucheng Lu',
#                  'Fucheng Road',
#                  'Fucheng Street',
#                  'Fuhua hospital',
#                  'Fumi Road',
#                  'Funjia Hotung',
#                  'Fuqian street',
#                  'Fuxing Road',
#                  'Fuxingmen Inner Avenue',
#                  'Fuyuan Road',
#                  'GAOJIAYUAN(Open soon)',
#                  'Gangyuan Park',
#                  'Ganlu Hutong',
#                  'Gaobeidian',
#                  'Ghost Laughing Stone',
#                  'Ghost street',
#                  'Ginza Shopping Center',
#                  'Global Village Peking University Reception',
#                  'Golden Hans',
#                  'Gongrentiyuchang East Road',
#                  'Gongrentiyuchang North Road',
#                  'Gongshang Bank',
#                  'Gongyixiqiao',
#                  'Gongzhufen',
#                  'Good Neighbors',
#                  'Great Fountain',
#                  'Great Wall of China',
#                  'Guananmen Inner Avenue',
#                  'Guananmen Outer Avenue',
#                  'Guang Shun North Street',
#                  'Guangcai Road',
#                  'Guanghua Road',
#                  'Guangqu road',
#                  'Guishui South Street',
#                  'Gulouwai Str',
#                  'Guomao',
#                  'Gushankou',
#                  'HAIDIAN Middle St',
#                  'HAIDIAN West St',
#                  'HAIDIANBEIYIJIE St',
#                  'HAIDIANDONGYIJIE St',
#                  'Haidan Wuluju',
#                  'Hall 4',
#                  'Hall of Prayer for Good Harvests',
#                  'Hall of Supreme Harmony',
#                  'Hangtian Bridge',
#                  'HeiQuan Road',
#                  'Heishanhu Road',
#                  'Heping West Bridge',
#                  'Hepingxiqiao',
#                  'Heqing Road',
#                  'Heyuan hostel actual location',
#                  'Home Inns',
#                  'Hongluosi Road',
#                  'Hongmenchuan River',
#                  'Houbajia Road',
#                  'Houbanbi Str',
#                  'Houhai Duck Marina',
#                  'Huai`an street',
#                  'Huaibaishu Str',
#                  'Huaigeng side road',
#                  'Huaihuang Hwy',
#                  'Huaihuang highway',
#                  'Huairou No.1 primary school',
#                  'Huairou No.2 middle school',
#                  'Huairou Public Bike',
#                  'Huangcunxidajie',
#                  'Huayuandongxiang',
#                  'Hufang Road',
#                  'Huixin Dongjie',
#                  'Huixin Xijie',
#                  'Hujialou North Street',
#                  'Huoyaoju Hutong',
#                  'ICBC',
#                  'IHEP Tua 2016',
#                  'Imperial Prospect Pavillion',
#                  'Information Center',
#                  'Inner Andingmen Str',
#                  'Inner Fuchengmen Str',
#                  'Inter-Terminal Line',
#                  'Interwest (Zhu Yu Cheng)',
#                  'Jenny Wang Shop',
#                  'Ji li Plaza',
#                  'Jiachangwutiao',
#                  'Jiaming Center',
#                  'Jiangbianchengwai',
#                  'Jiangtai',
#                  'Jiangtaicun Road',
#                  'Jianguo North Road',
#                  'Jianguo Road',
#                  'Jianguomen Bridge',
#                  'Jianguomen Outer Avenue',
#                  'Jianyuan Nanlu',
#                  'Jiaodaokoubei toutiao',
#                  'Jiaohuachang',
#                  'Jin Chun Yuan',
#                  'Jin Zhan Jia Yuan Block C',
#                  'JinJiang Fuyuan',
#                  'Jing Pin Jia Chang',
#                  'Jing-Mi Waterduct',
#                  'JingKeLong',
#                  'JingWangJiaYuanZhongJieNanKou',
#                  'Jingbao Line',
#                  "Jinggang'ao Expressway",
#                  'Jingguang Line',
#                  'Jinghailu',
#                  'Jinghu Expressway',
#                  'Jinghu Line',
#                  'Jingjintang Expressway',
#                  'Jingjiu Line',
#                  'Jingmi Road',
#                  'Jingqin Line',
#                  'Jingshan West Entrance',
#                  'Jingshen Highway',
#                  'Jingshi Expressway',
#                  'Jingtai expressway',
#                  'Jingxin Expressway ',
#                  'Jingzhang Expressway',
#                  'Jinrong Str',
#                  'Jintailu',
#                  'Jiugong',
#                  'Jiuxianqiao District',
#                  'Jiuzhong Bridge',
#                  'KFC',
#                  'Kai Fang Road',
#                  'Kaifang Roundabout',
#                  'Kangling Tomb',
#                  'Kehui Road',
#                  'Kexueyuan South Road',
#                  'Keyilu',
#                  'King Yue Bar',
#                  'LG Chem',
#                  'LIUFANG',
#                  'Langfang Santiao',
#                  'Langjia Alley',
#                  'Lanman Alley',
#                  'Lianbao Road',
#                  'Liangmaqiao',
#                  'Liangxiang University Town North',
#                  'Liangxiangnanguan',
#                  'Lianhuachi East Road',
#                  'Life List',
#                  'Life Science Park',
#                  'Linglong Road',
#                  'Lion & Tiger',
#                  'Lishuiqiao',
#                  'Lishuiqiao Park',
#                  'Litang road',
#                  'Litong Road',
#                  'Liujiadian',
#                  'Lixian Town',
#                  'Lize Road',
#                  'Luanqing Hutong',
#                  'Luopoling',
#                  'Luzhuang',
#                  'MAQUANYING',
#                  "Macdonald's",
#                  'Made in Beijing',
#                  'Madian Bridge East',
#                  'Mage Zhuangcun',
#                  'Majiapu',
#                  'Majiapu West Avenue',
#                  'Malianwa North Road',
#                  'Manjing Hutong',
#                  "McDonald's",
#                  'Meizha Alley',
#                  'Middle 8',
#                  'Middle Chegongzhuang Str',
#                  'Middle Majiabao Road',
#                  'Milu Park',
#                  'Mingede Road',
#                  'Minimart',
#                  'Miyun',
#                  'Modernista',
#                  'Mountain of Accumulated Elegance',
#                  'Museum of the Chinese People Resistance Against Japan',
#                  'Muslim Restaurant',
#                  'Mutianyu Road',
#                  'N 3rd Ring Rd. E',
#                  'N 3rd Ring Rd. Middle',
#                  'N 3rd Ring Rd. W',
#                  'N 4th Ring Rd.',
#                  'N 4th Ring Rd. E',
#                  'N 4th Ring Rd. W',
#                  'N. Andeli Str',
#                  'N. Fuchengmen Str',
#                  'N. Naoshikuo Str',
#                  'N. Sidiaokuo Str',
#                  'N. Xisi 1st Alley',
#                  'N. Xisi Str',
#                  'Nanbalizhuang',
#                  'Nanbanbidian',
#                  'Nanjixiang Hutong',
#                  'Nanlishilu',
#                  'Nanluoguxiang',
#                  'Nanxinhua street',
#                  'Nanyuan Avenue',
#                  'Narnia',
#                  'National Tennis Center',
#                  'New Shining Limited',
#                  'Nianhua Temple',
#                  'No.1 Instruction Building',
#                  'No.5 Instruction Building',
#                  'No.7 Middle School',
#                  'North 3rd Ring West Road',
#                  'North 5th Ring Road',
#                  'North Bathhouse',
#                  'North Chaoyang Road',
#                  'North China Electric Power University - Beijing Campus',
#                  'North Xiluoyun Road',
#                  'Old Civil Engineering Bldg',
#                  'Olympic Sports Center',
#                  'Outer Chongwenmen Str',
#                  'Outer Deshengmen Str',
#                  'Outer Jiugulou Str',
#                  'Outer Xinjiekou Str',
#                  'Outlets 798',
#                  'Pagoda of Cishou Temple',
#                  'Palace Moat',
#                  'Palms L.A. Kitchen and Bar',
#                  'Paoju Toutiao',
#                  'Peking Man Site at Zhoukoudian',
#                  'Phoenix Island',
#                  'Pingguoyuan',
#                  'Pits of canon fire of Japanese Force',
#                  'Pizza Hut',
#                  'Poly Theatre',
#                  'Professional Hair Salon',
#                  'Provincial Road 324',
#                  'Puhuangyu Road',
#                  'Pullman Hotel',
#                  'QS',
#                  'Qi He Lou Jie',
#                  'Qianhai North Side',
#                  'Qianhai West Street',
#                  'Qianluoquan Hutong',
#                  'Qianmen Avenue',
#                  'Qianmen West Street',
#                  'Qianmenxihe Str',
#                  'Qiantun',
#                  'Qidi Star',
#                  'Qingchun Road',
#                  'Qinghe',
#                  'Qinghe Zhong Street',
#                  'Qinghua East Road',
#                  'Qingyuan Road',
#                  'Qingyuanlu',
#                  'Qinian Street',
#                  'Qinxue Building',
#                  u'Qiónghuá Island',
#                  'Quanjude',
#                  'Residential Hall 1',
#                  'Ritan Park',
#                  'Ron Mexico',
#                  'Ronghua Nanlu; Rhonghua Zhonglu',
#                  'Ronghua nanlu',
#                  'S. 3rd Ring Road',
#                  'S. 3rd Ring Road W.',
#                  'S. Chegongzhuang Str',
#                  'S. Shoupakou Str',
#                  'SAIC Volkswagen',
#                  'SHANYUAN St',
#                  'San Yan Jing Hu Tong',
#                  'San Yuan Mei Yuan Milk Shop',
#                  'Sanbulao Alley',
#                  'Sandu He',
#                  'Sanlihe Road',
#                  'Sanyuanqiao',
#                  'Sanzuoqiao Alley',
#                  'Science Bldg',
#                  'Sculpting In Time',
#                  'Sculpting in Time',
#                  'Shahe University Park',
#                  'Shan che za lang Jianbing',
#                  'Shang Di 3 Street',
#                  'Shang Di 7 Street',
#                  'Shang Di East 2nd Road',
#                  'Shang Di East Road',
#                  'Shang Di Post Office',
#                  'Shang Di West Road',
#                  'Shangdi',
#                  'Shangzhai',
#                  'Shi Fang (Marble Boat)',
#                  'Shibei Alley',
#                  'Shichang',
#                  'Shijingshan Road',
#                  'Shops Keda',
#                  'Shoubi Hutong',
#                  'Shoukai Square',
#                  'Shuangjing',
#                  'Shuangqing Road',
#                  'Shunyi Station - Exit C',
#                  'Shuttle to Nanshan ski',
#                  'Sicence Parc South, West Road',
#                  'Side Road of Jing-shi Expressway',
#                  'Side Road of Xizhimen Wai Street',
#                  'Sijiminfu roast duck restaurant',
#                  'Sino-Japan Friendship Pavillion',
#                  'Slow boat bar',
#                  'Songjiazhuang',
#                  'South Huawei Road',
#                  'South Muxidi Road',
#                  'South Xibahe Road',
#                  'South Zhanghua Road',
#                  'South Zhongguancun Street',
#                  'Starbucks',
#                  'Steamed Noodles Restaurant',
#                  'Stele Pavillion',
#                  'Subway',
#                  'Sun Art Space',
#                  'Suncity bldg 1',
#                  u'Super 8 Motel',
#                  'Surprise Outlets',
#                  'Taiguan road',
#                  'Taiyuan Gate',
#                  'Temple of Earth Park',
#                  'Terminal 3',
#                  'Textbook Center',
#                  'The Birds Nest Stadium',
#                  'The Imperial Mansion, Marriott Executive Apartments',
#                  'The Sixth Tower of the North Side',
#                  'TianChen East Road',
#                  'Tiantan Road',
#                  'Tianua Mansion',
#                  'Tibetan Pagoda',
#                  'Ticket Office',
#                  'Tonghuihe North Road',
#                  'Tongzhuang',
#                  'Tous les jours',
#                  'Tree gallery and cafe',
#                  'Tsinghua University History Museum',
#                  'Tsinghua University Northwest Supermarket',
#                  'Tuanlicun',
#                  'UK visa application centre',
#                  'W. Hepingli Str',
#                  'W. Xinglong Str',
#                  'W. Yongdingmen Str',
#                  'W. Zuoanmen Str',
#                  'WDK Club',
#                  'WalMart',
#                  'Wall Park of Ming Dynasty',
#                  'Walmart',
#                  'Wangfujing Street',
#                  'Wanping City Wall',
#                  'Wanquanhe Rd.',
#                  'Watsons',
#                  'Wenhuayuan xilu',
#                  'Wenxueguan Lu',
#                  'Wenyu River',
#                  'West Balizhang Road',
#                  'West Heavenly Gate',
#                  'West Shuguang Road',
#                  'West Sports Ground',
#                  'West Xinghuo Road',
#                  'Westgate of the Peking University',
#                  "Worker's Gymnasium",
#                  'Wu Jin Ku',
#                  'Wucun North Road',
#                  'Wukesong',
#                  'Wumudicun',
#                  "XIN'GONG",
#                  "Xiang'er Alley",
#                  'Xiang-Quan Roundabout',
#                  'Xiangshan Road',
#                  'Xiannongtan Qian Street',
#                  'Xianyukou',
#                  'Xiao Ying West Road',
#                  'Xiaowuji Road',
#                  'Xiaoyu',
#                  u'Xia‘zhuang',
#                  'Xidan',
#                  'Xidawang Road',
#                  'Xifushouli',
#                  'Xiju',
#                  'Xilou Hutong',
#                  'Xinbao North',
#                  'Xing Shi Kou Road',
#                  'Xingfucun Middle Road',
#                  'Xingwu Lincun',
#                  'Xinhua Bookstore',
#                  'Xinjiekou',
#                  'Xinxi Road',
#                  'Xisi',
#                  'Xitucheng',
#                  'Xitucheng Road',
#                  'Xiyuan',
#                  'Xizhimen Avenue',
#                  'Xizhimen North Street',
#                  'Xnhua North Street',
#                  'Xuanwumen East Avenue',
#                  'Xuanwumen Inner Avenue',
#                  'Xuanwumen West Avenue',
#                  'Xuetang Road',
#                  'Xueyuan Road',
#                  'Yandu Hotel',
#                  'Yangjiaodeng Alley',
#                  'Yangyan highway',
#                  'Yanjia Hutong',
#                  'Yanxiu Rd',
#                  'Yaojia Alley',
#                  'Yaojiayuan Road',
#                  'Ying Bin Roundabout',
#                  'Yizhuang',
#                  'Yizhuang Bridge',
#                  'Yizhuang Culture Park',
#                  'Yizhuangqiao',
#                  'YongTai Zhong Road',
#                  'Yongding River',
#                  'Yongdingmen Bridge',
#                  'Yongdingmenwai Street',
#                  'Yongfeng',
#                  'Yongfeng South',
#                  'Yonghe King',
#                  'Yonghegong Lama Temple',
#                  'Youth League Committee',
#                  'Youwaixie Jie',
#                  'Yu Shi Hu Tong',
#                  'Yuan Da Road',
#                  'Yuandala',
#                  'Yuanmingyuan West Road',
#                  'Yujiayuan north',
#                  'Yunhe Ouest Avenue',
#                  'Yuquan Rd.',
#                  'Yuxin Huayuan West Road',
#                  'ZHUXINZHUANG East Road',
#                  'Zaoying',
#                  'Zhangguozhuang',
#                  'Zhangjiawan Cun',
#                  'Zhanlanguan Road',
#                  'Zhanzi Alley',
#                  'Zhaotangzi Hutong',
#                  'Zhenbian Fortress',
#                  'Zhenbiancheng',
#                  'Zheng Jue Hall',
#                  'Zhengyi Avenue',
#                  'Zhenxing Road',
#                  'Zhixin Road',
#                  'Zhongguancun Main Street',
#                  'Zhongguancun North Street',
#                  'Zhongguin Village East Road',
#                  'Zhongjingjidou',
#                  'Zhonglouwan Hutong',
#                  'Zhoujiazhuang Road',
#                  'Zijing Student Dormitory No. 14',
#                  'Zijing Student Dormitory No. 15',
#                  'Zizhu Bridge',
#                  'Zizhuyuan Road',
#                  'Zizhuyuan South Road',
#                  'caihonglu',
#                  'g&m Cafe',
#                  'jiangtailukoubei',
#                  u'lìshuǐ bridge west road',
#                  'mo shi kou street',
#                  'peiping machine brewing taproom',
#                  'red brick art museum',
#                  'rest. quanjude',
#                  'taipingzhuang North street',
#                  u'tàipíngzhuāng Center Road',
#                  u'wudaoku (quartier étudiant/pause déjeuner)',
#                  u'zhōngdōng road',
#                  'zishouyuan',
#                  u'Площадь Тианьмень',
#                  u'Храм Неба',
#                  u'四元桥'])}

# %% [markdown]
# 审查“name:en”字段，发现某些地址的英文名称中，存在过度简写的情况。如：“Aimin Str”。
# 另外，某些英文名称中，存在拼音直译的情况。如：“Anding Lu”。

# %% [markdown]
# ### 修正数据

# %% [markdown]
# #### 完善mapping

# %%
# 查找不规范命名
street_type_re = re.compile(r'\b\S+\.?$')
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

def is_street_enname(elem):
    return (elem.attrib['k'] == 'name:en')

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def audit(osm_file):
    osmfile = open(osm_file, 'r')
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osmfile, events = ("start",)):
        for tag in elem.iter('tag'):
            if is_street_enname(tag):
                audit_street_type(street_types, tag.attrib['v'])
    osmfile.close()
    pprint(sorted(street_types.iteritems(), key = lambda d:d[0]))

audit(OSM_FILE)
# Out:
# [('1',
#   set(['Beijing Subway Line 1',
#        'Building 1',
#        'Cafeteria No. 1',
#        'Capital Normal University - North Campus 1',
#        'No. 3 Teaching Bldg Sector 1',
#        'Residential Hall 1',
#        'Seasons Park bldg 1',
#        'Suncity bldg 1'])),
#  ('10', set(['Hall 10', 'Residential Hall 10'])),
#  ('101', set(['China National Highway 101'])),
#  ('102', set(['China National Highway 102'])),
#  ('104', set(['China National Highway 104'])),
#  ('105', set(['China National Highway 105'])),
#  ('106', set(['China National Highway 106'])),
#  ('107', set(['China National Highway 107'])),
#  ('108', set(['Bistrot 108', 'China National Highway 108'])),
#  ('109', set(['China National Highway 109'])),
#  ('11', set(['7 11', 'Residential Hall 11'])),
#  ('111', set(['China National Highway 111'])),
#  ('12', set(['Residential Hall 12'])),
#  ('13', set(['Beijing Subway Line 13', 'Sirteen 13'])),
#  ('1308', set(['1308'])),
#  ('14',
#   set(['International Office BIT, No. 14',
#        'Residential Hall 14',
#        'Subway Line 14',
#        'Zijing Student Dormitory No. 14'])),
#  ('15', set(['Zijing Student Dormitory No. 15'])),
#  ('16', set(['Beijing Subway, Line 16', 'Zijing Student Dormitory No. 16'])),
#  ('17', set(['Zijing Student Dormitory No. 17'])),
#  ('18', set(['Building 18', 'Zijing Student Dormitory No. 18'])),
#  ('19', set(['Building 19', 'Zijing Student Apartment Building 19'])),
#  ('2',
#   set(['BJU Beijing United Familiy Hospital Bldg. 2',
#        'Beijing Subway Line 2',
#        'Building 2',
#        'Capital Normal University - North Campus 2',
#        'Hall 2',
#        'Jiaodaokoubei 2',
#        'Residential Hall 2',
#        'Seasons Park bldg 2',
#        'Suncity bldg 2',
#        'Terminal 2',
#        'Zpark Road No 2',
#        'friend 2'])),
#  ('20', set(['Zijing Student Dormitory No. 20'])),
#  ('2016', set(['IHEP Tua 2016'])),
#  ('2017', set(['World Winter Sports Beijing 2017'])),
#  ('21', set(['Building 21', 'Zijing Student Dormitory No. 21'])),
#  ('22', set(['Zijing Student Dormitory No. 22'])),
#  ('23', set(['Zijing Student Dormitory No. 23'])),
#  ('24', set(['Building 24'])),
#  ('25', set(['Building 25'])),
#  ('26', set(['Building 26'])),
#  ('3',
#   set(['Airport terminal 3',
#        'Building 3',
#        'Hall 3',
#        'No. 3 Teaching Bldg Sectors 2, 3',
#        'Residential Hall 3',
#        'Seasons Park bldg 3',
#        'Suncity bldg 3',
#        'Terminal 3',
#        'friend 3'])),
#  ('324', set(['Provincial Road 324'])),
#  ('4',
#   set(['Building 4', 'Hall 4', 'Residential Hall 4', 'Seasons Park bldg 4'])),
#  ('48', set(['Bus #47, 48'])),
#  ('5',
#   set(['Building 5',
#        'Hall 5',
#        'Seasons Park bldg 5',
#        'Take 5',
#        'Yonghegong Lama Temple Station line 2 & 5'])),
#  ('51airgallery', set(['51airgallery'])),
#  ('526', set(['bus #526'])),
#  ('55', set(['Beijing 55'])),
#  ('58', set(['Swing Bar & Bistro 58'])),
#  ('6', set(['Beijing Subway Line 6'])),
#  ('7', set(['Building 7', 'Hall 7', 'Residential Hall 7'])),
#  ('7-11', set(['7-11'])),
#  ('7-Eleven', set(['7-Eleven'])),
#  ('798', set(['Cafe Flatwhite 798', 'Outlets 798'])),
#  ('8', set(['Building 8', 'Hall 8', 'Middle 8', 'Timezone 8'])),
#  ('864', set(['BJbus 864'])),
#  ('9', set(['Building 9', 'Hall 9', 'Residence 9', 'Residential Hall 9'])),
#  ('A',
#   set(['Beixinqiao Subway Line 5 Exit A',
#        'Exit A',
#        'Fortune Plaza Office Tower A',
#        'Jiarun Garden Building A',
#        'No. 6 Teaching Bldg Sector A',
#        'Shunyi Station - Exit A'])),
#  ('A)', set(['Jiaming Center (Block A)'])),
#  ('ACB)', set(['Audi China Building (ACB)'])),
#  ('AH1', set(['Asian Highway AH1'])),
#  ('AH3', set(['Asian Highway AH3'])),
#  ('APM', set(['APM'])),
#  ('ATM', set(['Bank of China ATM', 'ICBC ATM'])),
#  ('Abstinence', set(['Palace of Abstinence'])),
#  ('Academy', set(['Beijing Film Academy', 'China Music Academy'])),
#  ('Activities', set(['Center for Student Cultural Activities'])),
#  ('Administration',
#   set(['Administration', 'University of Modern Administration'])),
#  ('Affairs', set(['Ministry of Foreign Affairs'])),
#  ('Aggression',
#   set(['Museum of the Chinese People Resistance Against Japanese Aggression'])),
#  ('Agriculture', set(['Beijing University of Agriculture'])),
#  ('Air', set(['Smart Air'])),
#  ('Airbase', set(['Zhuozhou Airbase'])),
#  ('Airbnb', set(['Kyle Airbnb'])),
#  ('Airport',
#   set(['Beijing Capital International Airport', 'Beijing Nanyuan Airport'])),
#  ('Alley',
#   set(['Babukou Alley',
#        'Baimicang Alley',
#        'Banchang Alley',
#        'Banqiao Alley',
#        'Baochan Alley',
#        'Baochao Alley',
#        'Beibingmasi Alley',
#        'Beicaochang Alley',
#        'Beigouyan Alley',
#        'Beiguanfang Alley',
#        'Beiluogu Alley',
#        'Beixiangfeng Alley',
#        'Beixincang Alley',
#        'Beixing Alley',
#        'Beixinping Alley',
#        'Bifeng Alley',
#        'Bingbuwa Alley',
#        'Boluocang Alley',
#        'CAIHEFANG West Alley',
#        'Cangjingguan Alley',
#        'Cangnan Alley',
#        'Caochang Batiao Alley',
#        'Chaibang Alley',
#        'Cheniandian Alley',
#        'Dafang Alley',
#        'Dafangjia Alley',
#        'Dagobe Alley',
#        'Daguaibang Alley',
#        'Dahoucang Alley',
#        'Dajiao Alley',
#        'Dajinsi Alley',
#        'Daju Alley',
#        'Damucang Alley',
#        'Dashibei Alley',
#        'Dashihu Alley',
#        'Daxiangfeng Alley',
#        'Daxing Alley',
#        'Dayangjia Alley',
#        'Dazongan Alley',
#        'De Hua Li Alley',
#        'DongGuanYing Alley',
#        'Dongbuyaqiao Alley',
#        'Dongchang Alley',
#        'Dongguanfang Alley',
#        'Dongjiaomin Alley',
#        'Donglangxia Alley',
#        'Dongmencang Alley',
#        'Dongmianhua Alley',
#        'Dongqiangchang Alley',
#        'Dongsi 11th Alley',
#        'Dongsi 12th Alley',
#        'Dongsi 13th Alley',
#        'Dongsi 14th Alley',
#        'Dongsi 1st Alley',
#        'Dongsi 2nd Alley',
#        'Dongsi 3rd Alley',
#        'Dongsi 4th Alley',
#        'Dongsi 5th Alley',
#        'Dongsi 6th Alley',
#        'Dongsi 7th Alley',
#        'Dongsi 8th Alley',
#        'Dongsi 9th Alley',
#        'Dongtanze Alley',
#        'Dongtao Alley',
#        'Dongwang Alley',
#        'Dongzhongbu Alley',
#        'Douban Alley',
#        'Doufuchi Alley',
#        'E. Kaiyangli Alley',
#        'Fangjia Alley',
#        'Fangzhuanchang Alley',
#        'Fensiting Alley',
#        'Fuxiang Alley',
#        'Ganyu Alley',
#        'Gongmenkou 1st Alley',
#        'Gongmenkou 2rd Alley',
#        'Gongmenkou 3rd Alley',
#        'Gongmenkou 4th Alley',
#        'Guangan Alley',
#        'Guangze Alley',
#        'Guosheng Alley',
#        'Guoxiang Alley',
#        'Guoxing Alley',
#        'Haiyuncang Alley',
#        'Hangkong Alley',
#        'Heizhima Alley',
#        'Hongjing Alley',
#        'Hongshan Alley',
#        'Houguangping Alley',
#        'Houmacheng Alley',
#        'Houmao Alley',
#        'Houyingfang Alley',
#        "Houyuan'ensi Alley",
#        'Huapichang Alley',
#        'Huayuan Alley',
#        'Hucang Alley',
#        'Jiaozi Alley',
#        'Jingtu Alley',
#        'Jinguo Alley',
#        'Jingyang Alley',
#        'Jinjiang Alley',
#        'Jinsi Alley',
#        "Ju'er Alley",
#        'Langjia Alley',
#        'Lanman Alley',
#        'Liangguochang Alley',
#        'Lingguang Alley',
#        'Lingjing Alley',
#        'Liuhai Alley',
#        'Lumicang Alley',
#        "Luo'er Alley",
#        "Mao'er Alley",
#        'Meizha Alley',
#        'Menlou Alley',
#        'Mianhua Alley',
#        'N. Xisi 1st Alley',
#        'N. Xisi 2rd Alley',
#        'N. Xisi 3rd Alley',
#        'N. Xisi 4th Alley',
#        'N. Xisi 5th Alley',
#        'N. Xisi 6th Alley',
#        'N. Xisi 7th Alley',
#        'N. Xisi 8th Alley',
#        'Nanbanqiao Alley',
#        'Nangongjiangying Alley',
#        'Nanmencang Alley',
#        'Nanwei Road South Alley',
#        'Nanxinping Alley',
#        'Paoju Alley',
#        'Pener Alley',
#        'Picai Alley',
#        'Qianche Alley',
#        'Qianfu Alley',
#        'Qiangongyong Alley',
#        'Qianguanping Alley',
#        'Qiangulouyuan Alley',
#        'Qianmachang Alley',
#        'Qianmao Alley',
#        'Qianxiaojia Alley',
#        "Qianyuan'ensi Alley",
#        'Qinlao Alley',
#        'Qunli Alley',
#        'Sanbulao Alley',
#        'Sanzuoqiao Alley',
#        'Shajing Alley',
#        'Shangqin Alley',
#        'Shanlao Alley',
#        'Shi Qiao Alley',
#        'Shibei Alley',
#        'Shijinhuayuan Alley',
#        'Shique Alley',
#        'Shuiche Alley',
#        'Sihuan Alley',
#        'South Luogu Alley',
#        'Suoyi Alley',
#        'Tieying Alley',
#        'W. Kaiyangli Alley',
#        'Wangzhima Alley',
#        'Wangzuo Alley',
#        'Weijia Alley',
#        'Weikeng Alley',
#        'Wudaoying Alley',
#        'Wulao Alley',
#        "Xiang'er Alley",
#        'Xiaohongluochang Alley',
#        'Xiaoju Alley',
#        'Xiaoqudeng Alley',
#        'Xiaoshibei Alley',
#        'Xiaoshiqiao Alley',
#        'Xiaowei Alley',
#        'Xiaoxiangfeng Alley',
#        'Xiaoyou Alley',
#        'Xiezuo Alley',
#        'Xiguan Alley',
#        'Ximeichang Alley',
#        'Xingfu Yicun 4th Alley',
#        'Xinghua Alley',
#        'Xinsi Alley',
#        'Xirongxian Alley',
#        'Xisongshu Alley',
#        'Xitao Alley',
#        'Xitiejiang Alley',
#        'Xiyangwei Alley',
#        'Xizhong Alley',
#        'Xizongbu Alley',
#        'Xueyuan Alley',
#        "Ya'er Alley",
#        'Yangfang Alley',
#        'Yangjiaodeng Alley',
#        'Yannian Alley',
#        'Yaojia Alley',
#        'Yihua Alley',
#        'Yongheng Alley',
#        'Yongkang Alley',
#        'Youfang Alley',
#        'Yude Alley',
#        'Yuyou Alley',
#        u'Yu’er Alley',
#        'Zhanzi Alley',
#        'Zhengjue Alley',
#        'Zhongtao Alley',
#        'Zhuzhong Alley'])),
#  ('Alsafir', set(['Alsafir'])),
#  ('Altar', set(['Circular Mound Altar'])),
#  ('America', set(['Embassy of the United States of America'])),
#  ('Amusement', set(['Harmonic Amusement'])),
#  ('Anding', set(['Anding'])),
#  ('Andingmen', set(['Andingmen'])),
#  ('Angezhuangcun', set(['Angezhuangcun'])),
#  ('Anhuaqiao', set(['Anhuaqiao'])),
#  ('Anjialou', set(['Anjialou'])),
#  ('Anlilu', set(['Anlilu'])),
#  ('Anzhenmen', set(['Anzhenmen'])),
#  ('Apartment',
#   set(['Suyuan Apartment',
#        'Xiangyuan Apartment',
#        'Yayuan Apartment',
#        'Yiyuan Apartment'])),
#  ('Apartments',
#   set(['Fortune Garden Apartments',
#        'The Imperial Mansion, Marriott Executive Apartments'])),
#  ('Arcade', set(['Sanlitun Shopping Arcade'])),
#  ('Archives', set(['Archives'])),
#  ('Area',
#   set(['Baige Service Area',
#        'Donfeng Area',
#        'Happy Valley Scenic Area',
#        'QiXingYuan Residential Area',
#        'Ritan Park Rock Climbing Area',
#        'Tsinghua University Heqingyuan Residential Area',
#        'Tsinghua University Northwest Residential Area'])),
#  ('Argentina', set(['Embassy of the Republic of Argentina'])),
#  ('Art',
#   set(['Central Academy of Fine Art',
#        'Tang Contemporary Art',
#        'UCCA Ullens Center for Contemporary Art'])),
#  ('Arts',
#   set(['China Institute of Arts', 'National Centre for the Performing Arts'])),
#  ('Attained', set(['Tempe of Wisdom Attained'])),
#  ('Auditorium', set(['Auditorium', 'New Tsinghua Auditorium'])),
#  ('Auditory', set(['Dining Hall and Auditory'])),
#  ('Australia', set(['Embassy of Australia'])),
#  ('Aviarry', set(['Aviarry'])),
#  ('B',
#   set(['Beixinqiao Subway Line 5 Exit B',
#        'Exit B',
#        'HujiaLou Subway Line 10 Exit B',
#        'Jiarun Garden Building B',
#        'No. 6 Teaching Bldg Sector B',
#        'Shunyi Station - Exit B'])),
#  ('B)', set(['Jiaming Center (Block B)'])),
#  ('BAYJH', set(['BAYJH'])),
#  ('BBQ', set(['Ju Dian BBQ'])),
#  ('BBQ)', set(['greedy cat BBQ (Chanzuimao BBQ)'])),
#  ('BEIXIANG', set(['ZHIDE BEIXIANG'])),
#  ('BIT)', set(['Beijing Institute of Technology (BIT)'])),
#  ('BJDW', set(['BJDW'])),
#  ('BMW', set(['BMW'])),
#  ('BNU)', set(['Beijing Normal University (BNU)'])),
#  ('BREAD', set(['there will be BREAD'])),
#  ('BUFFET', set(["JIM'S BUFFET"])),
#  ('Babaoshan', set(['Babaoshan'])),
#  ('Babaozhang', set(['Babaozhang'])),
#  ('Badaling', set(['Badaling'])),
#  ('Bagou', set(['Bagou'])),
#  ('Baguette', set(['Paris Baguette'])),
#  ('Bahuashenchu', set(['Bahuashenchu'])),
#  ('Baiduizi', set(['Baiduizi'])),
#  ('Baifu', set(['Baifu'])),
#  ('Baijiachang', set(['Baijiachang'])),
#  ('Baitasi', set(['Baitasi'])),
#  ('Baiziwan', set(['Baiziwan'])),
#  ('Bakery', set(['Auspicious Phoenix Cafe and Bakery', 'Holiland Bakery'])),
#  ('Baliqiao', set(['Baliqiao'])),
#  ('Banjiehe', set(['Banjiehe'])),
#  ('Bank',
#   set(['Bank',
#        'China CITIC Bank',
#        'China Construction Bank',
#        'China Everbright Bank',
#        'China Merchant Bank',
#        "China Merchant's Bank",
#        'China Merchants Bank',
#        'Construction Bank',
#        'Gongshang Bank',
#        'Huaxia Bank',
#        'Postal Saving Bank',
#        'SPD Bank',
#        'Woori Bank'])),
#  ('Baocun', set(['Gaojia Baocun'])),
#  ('Bar',
#   set(['60 Bar',
#        "Georgia's feast Restaurant & Bar",
#        "Harry's Bar",
#        'King Yue Bar',
#        'Mai Bar',
#        'Mai Fresh Restaurant and Bar',
#        'Noodles Bar',
#        'Palms L.A. Kitchen and Bar',
#        'Temple Bar',
#        'TooBoom Bar',
#        'Vade Bar',
#        'mao mao Chong Bar'])),
#  ('Bar)', set(['Apothecary (Bar)', 'C2H60 (Bar)', 'la social (Bar)'])),
#  ('Base',
#   set(['Beijing Shahezhen Air Base',
#        'Beijing Tongxian Air Base',
#        'Biomedical Base',
#        'Liangxiangzhen Air Base'])),
#  ('Bathhouse', set(['North Bathhouse'])),
#  ('Batiao', set(['Caochang Batiao'])),
#  ('Bazaar', set(['Lotus Bazaar'])),
#  ('Bears', set(['Bears', 'White Bears'])),
#  ('Beer', set(['Craft Beer'])),
#  ('BeiKou', set(['JingWang JiaYuan ZhongJie BeiKou'])),
#  ('Beianhe', set(['Beianhe'])),
#  ('Beigangzi', set(['Beigangzi'])),
#  ('Beigong', set(['Beigong'])),
#  ('Beigongdaximen', set(['Beigongdaximen'])),
#  ('Beigongmen', set(['Beigongmen'])),
#  ('Beiguan', set(['Tongzhou Beiguan'])),
#  ('Beihecun', set(['Beihecun'])),
#  ('Beijie', set(['Shatan Beijie'])),
#  ('Beijing',
#   set(['Bank of Beijing',
#        'Beijing',
#        'Beit Chabad Beijing',
#        'Best Western Olympic Stadium Hotel Beijing',
#        'China University of Geosciences at Beijing',
#        'China University of Mining and Technology at Beijing',
#        'Entry-Exit Administration Service Center, Public Security Bureau of Beijing',
#        'Exit & Entry Administration Service Center, Public Service Bureau of Beijing',
#        'Four Seasons Hotel Beijing',
#        'German Embassy School of Beijing',
#        'Grand Millennium Beijing',
#        'Harrow International School Beijing',
#        'Howard Johnson Paragon Hotel Beijing',
#        'IKEA Beijing',
#        'International School of Beijing',
#        'Jianguo Hotel Beijing',
#        'Kehilat Beijing',
#        'Made in Beijing',
#        'Pace Beijing',
#        'Romanian Cultural Center in Beijing',
#        'St Regis Beijing',
#        'The International Montessory School of Beijing',
#        'The first experimental primary school in Beijing',
#        'University of Science and Technology Beijing',
#        'Vienna Hotel Beijing',
#        "Wolfgang's Steakhouse by Wolfgang Zwiener Beijing"])),
#  ('Beijing)',
#   set(['Beijing railway museum (Former Railway Station of Beijing)'])),
#  ('Beijing-Grand-Bridge', set(['Beijing-Grand-Bridge'])),
#  ('Beikou', set(['Huixinxijie Beikou'])),
#  ('Beili', set(['Shaoyaoju Beili'])),
#  ('Beilu', set(['Ronghua Beilu', 'Xihuan Beilu'])),
#  ('Beiqiao', set(['Dongfeng Beiqiao'])),
#  ('Beishaowa', set(['Beishaowa'])),
#  ('Beishatan', set(['Beishatan'])),
#  ('Beitucheng', set(['Beitucheng'])),
#  ('Beixiang', set(['Caochang Beixiang'])),
#  ('Beixincun', set(['Beixincun'])),
#  ('Beixinqiao', set(['Beixinqiao'])),
#  ('Beixinzhuang', set(['Beixinzhuang'])),
#  ('Beixinzhuangcun', set(['Beixinzhuangcun'])),
#  ('Beiyuan', set(['Beiyuan', 'Tongzhou Beiyuan'])),
#  ('Beizhai', set(['Beizhai'])),
#  ('Bell', set(['Ancient Bell'])),
#  ('Berlin', set(['Zeit Berlin'])),
#  ('Berrybeans', set(['Berrybeans'])),
#  ('BiQiao', set(['BiQiao'])),
#  ('Bianyifang', set(['Bianyifang'])),
#  ('Bike', set(['Huairou Public Bike'])),
#  ('Bingwu', set(['Huilifa Bingwu'])),
#  ('Bird', set(['Lucky Bird'])),
#  ('Bld', set(['Medical Science Bld'])),
#  ('Bldg',
#   set(['Biology Bldg',
#        'Chemistry Bldg',
#        'East Main Bldg',
#        'Energy Sciences Bldg',
#        'Engineering Physics Bldg',
#        'Former Dormitory Bldg',
#        "He'er Bldg",
#        'Lee Shau-kee Science and Technology Bldg',
#        'Life Sciences Bldg',
#        'Liquid Crystal Bldg',
#        'Main Bldg',
#        'Mechanical Engineering Bldg',
#        'Mong Man-wei Science Technology Bldg',
#        'Nanotechnology Bldg',
#        'New Chemistry Bldg',
#        'New Hydraulic Engineering Bldg',
#        'No. 1 Teaching Bldg',
#        'No. 2 Teaching Bldg',
#        'No. 4 Teaching Bldg',
#        'No. 5 Teaching Bldg',
#        'Old Civil Engineering Bldg',
#        'Renhuan Bldg',
#        'Science Bldg',
#        'Sciences Bldg',
#        'Sedimentation Bldg',
#        'Sino-Italian Tsinghua Environment and Energy-Efficient Bldg',
#        'Technology and Science Bldg',
#        'Tsinghua-Rom Electronic Engineering Bldg',
#        'Welding Bldg',
#        'Wenbei Bldg',
#        'Wennan Bldg',
#        'Wenxi Bldg',
#        'West Main Bldg',
#        'Xue Yan Bldg'])),
#  ('Bldg)', set(['Department of Precision Instruments (9003 Bldg)'])),
#  ('Blessings', set(['Pavilion of Great Blessings'])),
#  ('Boat)', set(['Shi Fang (Marble Boat)'])),
#  ('Bookstore',
#   set(['Beijing Foreign Languages Bookstore', 'Xinhua Bookstore'])),
#  ('Botanica', set(['Botanica'])),
#  ('Box', set(['Coffee Box'])),
#  ('Brewery', set(['Grizzly Swiss BBQ and Brewery'])),
#  ('Brewing', set(['Great Leap Brewing'])),
#  ('Brewpub', set(['Ram Brewpub'])),
#  ('Bridge',
#   set(['17 Arch Bridge',
#        'Baiyun Bridge',
#        'Balizhuang Bridge',
#        'Beiyuan Bridge',
#        'Chedaogou Bridge',
#        u'Chánggēng Bridge',
#        'Ciyunsi Bridge',
#        'Dahuangzhuang Bridge',
#        'Danbi Bridge',
#        'Dayangfang Bridge',
#        'Dinghui Bridge',
#        'Fuxing Bridge',
#        'Fuxingmen Bridge',
#        'GUOTU Bridge',
#        'Guananmen Bridge',
#        'Guanghua Bridge',
#        'Guanghui Bridge',
#        'Guangshun Bridge',
#        'Guanqumen Bridge',
#        'Guomao Bridge',
#        'Hangtian Bridge',
#        'Heping East Bridge',
#        'Heping West Bridge',
#        'Huairou Bridge',
#        'Huichengmen Bridge',
#        'Jade Belt Bridge',
#        'Jianguomen Bridge',
#        'Jinding Bridge',
#        'Jingguang Bridge',
#        'Jinjiacun Bridge',
#        'Jiuzhong Bridge',
#        'Lianfang Bridge',
#        'Lianfang East Bridge',
#        'Liangma Bridge',
#        'Lianyu Bridge',
#        'Liujiayao Bridge',
#        'Lugu Bridge',
#        'Marco Polo Bridge',
#        'Nanshawo Bridge',
#        'Pingfang Bridge',
#        'Ronghua Bridge',
#        'Ruin of Arc Bridge',
#        'Ruin of Iris Bridge',
#        'Shifeng Bridge',
#        'Sitong Bridge',
#        'Tianjin Grand Bridge',
#        'Willow Bridge',
#        'Wujing Bridge',
#        'Xiangquan Bridge',
#        'Xibianmen Bridge',
#        'Xuezhi Bridge',
#        'Yamenkou Bridge',
#        'Yang Bridge',
#        'Yinding Bridge',
#        'Yizhuang Bridge',
#        'Yongan Bridge',
#        'Yongdingmen Bridge',
#        'Yushuguan Bridge',
#        'Yuting Bridge',
#        'Zhaogongkou Bridge',
#        'Zhengyang Bridge',
#        'Zizhu Bridge'])),
#  ('Bridges', set(['Inner Golden River Bridges'])),
#  ('Bros', set(['Moka Bros'])),
#  ('Brotzeit', set(['Brotzeit'])),
#  ('Bu', set(['Tong Feng Bu'])),
#  ('Building',
#   set(['Bathroom Building',
#        'Beihang, New Main Building',
#        'Chang Guan Building',
#        'China Aviation Tech Building',
#        'China Investment Building',
#        'China Resources Building',
#        'Conference Center at New Main Building',
#        'Dascom Building',
#        'Eight One Building',
#        'Grand Building',
#        'Hanwang Building',
#        'Jingyi Sci-Tech Building',
#        'Lab Building',
#        'Leo KoGuan Building',
#        'Music and Art Building',
#        'No.1 Instruction Building',
#        'No.2 Instruction Building',
#        'No.3 Instruction Building',
#        'No.4 Instruction Building',
#        'No.5 Instruction Building',
#        'Office Building',
#        'Qinxue Building',
#        'Qiushi Building',
#        'Renji Building',
#        'Sigma Building',
#        'Suyuan Office Building',
#        'Xiangyu Building',
#        'Zhixing Building',
#        'Zhong Fang Building'])),
#  ('Building)',
#   set(['IBM China Software Development Lab (Dascom Building)',
#        'IBM China Software Development Lab (Diamond Building)',
#        'IBM China Software Development Lab (Ring Building)'])),
#  ('Building11', set(['Building11'])),
#  ('Bungalow', set(['Tiki Bungalow'])),
#  ('Bureau', set(['Beijing Human Resources & Social Security Bureau'])),
#  ('Burgers', set(['Qing Qing Burgers'])),
#  ('Byway', set(['Yandai Byway'])),
#  ('C',
#   set(['Beixinqiao Subway Line 5 Exit C',
#        'Exit C',
#        'Jiarun Garden Building C',
#        'Jin Zhan Jia Yuan Block C',
#        'No. 6 Teaching Bldg Sector C',
#        'Shunyi Station - Exit C',
#        'Yong He Gong Lama Temple Subway Line 2 & 5 Exit C',
#        'Yonghegong Lama Temple Subway Line 5 Exit C'])),
#  ('C1', set(['Exit C1'])),
#  ('C2', set(['Exit C2'])),
#  ('CAS',
#   set(['Institute of High Energy Physics, CAS',
#        'National Astronomical Observatories, CAS',
#        'National Space Science Center, CAS'])),
#  ('CIEC', set(['New CIEC'])),
#  ('COFFEE', set(['YOUNEE COFFEE'])),
#  ('CPC', set(['Central School of CPC'])),
#  ('CUIGEZHUANG', set(['CUIGEZHUANG'])),
#  ('Cafe',
#   set(['BYY Internet Cafe',
#        'Naifen Dessert Cafe',
#        'Poetry Cafe',
#        'Qing Qing Times Cafe',
#        'Time Cafe',
#        'Via Cafe',
#        'With Cafe',
#        'Wu Jin Cafe',
#        'Zero-One Times Cafe',
#        'Zoo Cafe',
#        'g&m Cafe'])),
#  (u'Café', set([u'The Hollywood Café'])),
#  ('CaiHongLu', set(['CaiHongLu'])),
#  ('Caihuying', set(['Caihuying'])),
#  ('Caishikou', set(['Caishikou'])),
#  ('Campus',
#   set(['Beijing Institute of Technology - Fangshan Campus',
#        'Beijing No.4 High School - East Campus',
#        'Beijing Technology and Business University - East Campus',
#        'Beijing University of Chemical Technology - West Campus',
#        'Beijing University of Civil Engineering and Architecture - Xicheng Campus',
#        'Capital Normal University - East Campus',
#        'Chen Jinglun Middle School - East Campus',
#        'Chen Jinglun Middle School - Jiaming Campus',
#        'China Agricultural University - East Campus',
#        'China University of Petroleum - Beijing Campus',
#        'North China Electric Power University - Beijing Campus',
#        'Zhong Guan Cun 2nd School Shangdi Campus'])),
#  ('Campus)',
#   set(['Dulwich College Beijing (Legend Garden Campus)',
#        'Dulwich College Beijing (Riviera Campus)'])),
#  ('Can', set(['U Can'])),
#  ('Canada', set(['Embassy of Canada'])),
#  ('Canal', set(['Grand Canal', 'Landmark Canal'])),
#  ('Cangtoucun', set(['Cangtoucun'])),
#  ('Canteen',
#   set(['Baotsi Canteen',
#        'Bei Yuan Canteen',
#        'Ding Xiang Yuan Canteen',
#        'Guan Chou Yuan Canteen',
#        'He Yuan Canteen',
#        'Qing Fen Canteen',
#        'Tao Li Yuan Canteen',
#        'Ting Tao Yuan Canteen',
#        'University 7th Canteen',
#        'Wen Xin Yuan Canteen',
#        'Xi Chun Yuan Canteen',
#        'Yu Shu Yuan Canteen',
#        'Zhi Lan Yuan Canteen',
#        'Zijing Yuan Canteen'])),
#  ('CaoChangDi', set(['CaoChangDi'])),
#  ('Caofang', set(['Caofang'])),
#  ('Caoqiao', set(['Caoqiao'])),
#  ('Caravan', set(['Caravan'])),
#  ('Cargo', set(['Club Cargo'])),
#  ('Carrefour', set(['Carrefour'])),
#  ('Cathedral', set(["St. Joseph's Wangfujing Cathedral"])),
#  ('Cave',
#   set(['Hall of a Myriad Buddhas and Kongshui Cave', 'Stone-Flower Cave'])),
#  ('Center',
#   set(['Agricultural Exhibition Center',
#        'Architectural Design Center',
#        'Baush and Lomb Eye Care Center',
#        'Beijing Exhibition Center',
#        'Beijing International Convention Center',
#        'Beijing Lufthansa Center',
#        'Beijing NW Thermal Gas Power Center',
#        'Beijing SW Thermal Gas Power Center',
#        'Beijing Yanqi Lake International Convention & Exhibition Center',
#        'China Culture Center',
#        'China International Exhibition Center',
#        'China National Convention Center',
#        'China Tibetology Research Center',
#        'Community Service Center',
#        'Danish Culture Center',
#        'Education and Conservation Center',
#        'Environmental Development Center',
#        'Fitness Center',
#        'Fundamental Industrial Training Center',
#        'Ginza Shopping Center',
#        'Haidian Clinic of Beijing International Travel Healthcare Center',
#        'Henderson Center',
#        'Huairou Public Bike Management And Service Center',
#        'Huilongguan Sports Center',
#        'Information Center',
#        'International Education Communication Center',
#        'International Students Center',
#        'Jialong International Center',
#        'Jiaming Center',
#        'Kempinski Hotel Beijing Lufthansa Center',
#        'Mountain Art Beijing Frank Lin Art Center',
#        'National Aquatics Center',
#        'National Tennis Center',
#        'North Star Shopping Center',
#        'Olympic Sports Center',
#        'Peking University Health Science Center',
#        'Phoenix International Media Center',
#        'Printing Center',
#        'Property Management Center',
#        'Shangdi Residential Service Center',
#        'Sports Center',
#        'Student Health Center',
#        'Student Services Center',
#        'Textbook Center',
#        'Volkswagen Experience Center',
#        'WDK Shopping Center',
#        'Yansha Lufthansa Shopping Center',
#        'Zhongguancun La Vita Shopping Center'])),
#  ('Centre', set(['Ole Sports Centre'])),
#  ('Chabad', set(['Chabad'])),
#  ('Chaichangtun', set(['Chaichangtun'])),
#  ('Chang', set(['Jing Pin Jia Chang'])),
#  ('ChangDianXiaoQuXiJie', set(['ChangDianXiaoQuXiJie'])),
#  ('Changchunjie', set(['Changchunjie'])),
#  ('Changchunqiao', set(['Changchunqiao'])),
#  ('Changcun', set(['Guojia Changcun'])),
#  ('Changdiancun', set(['Changdiancun'])),
#  ('Changping',
#   set(['Changping',
#        'China University of Political Science and Law at Changping',
#        'The government of Changping'])),
#  ('Changyang', set(['Changyang'])),
#  ('Changying', set(['Changying'])),
#  ('Chaoyang', set(['Chaoyang'])),
#  ('Chaoyangmen', set(['Chaoyangmen', 'N. Chaoyangmen'])),
#  ('Chawu', set(['Chawu'])),
#  ('Chedaogou', set(['Chedaogou'])),
#  ('Chegongzhuang', set(['Chegongzhuang'])),
#  ('Chem', set(['LG Chem'])),
#  ('Cheng', set(['Huang Hua Cheng'])),
#  ('Cheng)', set(['Interwest (Zhu Yu Cheng)'])),
#  ('Chengcun', set(['Xilu Chengcun'])),
#  ('Chengshousi', set(['Chengshousi'])),
#  ('Chenxiyuan', set(['Chenxiyuan'])),
#  ('Chenzhuangzicun', set(['Chenzhuangzicun'])),
#  ('China',
#   set(['Bank Of China',
#        'Bank of China',
#        'China',
#        'Communication University of China',
#        'Eunuch Museum of China',
#        'Great Wall of China',
#        'Great wall of China',
#        'Minzu University of China',
#        'National Museum of China',
#        'Renmin University of China',
#        'Training Centre. Red Cross of China',
#        'Zero Point of Highways China'])),
#  ('Ching-Ling', set(['Former Residence of Soong Ching-Ling'])),
#  ('Chongwenmen', set(['Chongwenmen'])),
#  ('Church',
#   set(['Beijing Christian Chongwenmen Church',
#        'Beijing Kuanjik Christian Church',
#        'Haidian Christian Church',
#        'Our Lady of Mount Carmel (West Church'])),
#  ('Churrascos', set(['Brazilian Churrascos'])),
#  ('Cinema', set(['East Gate Cinema'])),
#  ('Ciqikou', set(['Ciqikou'])),
#  ('Ciqu', set(['Ciqu'])),
#  ('Circle', set(['Club Circle'])),
#  ('Cishousi', set(['Cishousi'])),
#  ('City',
#   set(['Baoding City',
#        'Chaoyang Joy City',
#        'Forbidden City',
#        'Langfang City',
#        'Raffles City',
#        'Sanhe City',
#        'The Underground City',
#        'Wall of Forbidden City',
#        'Wanping City',
#        'Xidan Joy City',
#        'Zhangjiakou City',
#        'Zhuozhou City',
#        'iShine City'])),
#  ('Cliff', set(['Monkey Cliff'])),
#  ('Clinic', set(['ARRAIL International Dental Clinic'])),
#  ('Clouds', set(['Temple of Azure Clouds'])),
#  ('Club',
#   set(['Aroma Zen Tea Club',
#        'Beijing International Club',
#        'E.T. Climbing Club',
#        'Vertigo Gecko Climbing Club',
#        'WDK Club'])),
#  ('Co', set(['Dizhen Silk Producte Co'])),
#  ('Co.,Ltd', set(['China TransInfo Technology Co.,Ltd'])),
#  ('Co.Ltd', set(['AutoNavi Software Co.Ltd'])),
#  ('Coffee',
#   set(['Barista Coffee',
#        'CL Coffee',
#        'Daily Roast Coffee',
#        'Fresh Bean Coffee',
#        'Hypervic Coffee',
#        'Pacific Coffee',
#        'Paradiso Coffee',
#        'Soloist Coffee',
#        'Starbucks Coffee',
#        'Tree House Coffee',
#        'Twosome Coffee',
#        'UBC Coffee',
#        'Voyage Coffee',
#        'Water Stone Coffee'])),
#  ('Coffees', set(["Gloria Jean's Coffees"])),
#  ('Coffetel', set(['James Joyce Coffetel'])),
#  ('College',
#   set(['Beijing Administrative College',
#        'Beijing Information Vocational and Technical College',
#        'Beijing Union College',
#        'Imperial College',
#        'Schwartman College'])),
#  ('Committee', set(['Youth League Committee'])),
#  ('Communication', set(['Bank of Communication'])),
#  ('Communications', set(['Bank of Communications'])),
#  ('Community', set(['Anyuanli Community', 'Huixinli Community'])),
#  ('Compound',
#   set(['Diplomatic Residence Compound', 'Russian Embassy Compound'])),
#  ('Concept', set(['Three Gun Living Concept'])),
#  ('Confucius', set(['Cafe Confucius'])),
#  ('Continua', set(['Galeria Continua'])),
#  ('CornerTower', set(['CornerTower'])),
#  ('Corporation', set(['China Banknote Printing and Minting Corporation'])),
#  ('Corridor', set(['Long Corridor'])),
#  ('Costa', set(['Costa'])),
#  ('Counter', set(['Burger Counter'])),
#  ('County',
#   set(['Dachang Hui Autonomous County',
#        "Gu'an County",
#        'Huailai County',
#        'Laishui County',
#        'Xianghe County',
#        'Yanqing County',
#        'Yongqing County'])),
#  ('County)', set(['Grand Canal Peacock City, Wenshajun (Windsor County)'])),
#  ('Courts', set(['Basketball Courts', 'Tennis Courts', 'Volleyball Courts'])),
#  ('Courtyard', set(['Dali Courtyard', 'Tangfang Courtyard'])),
#  ('Crush', set(['Chili Crush'])),
#  ('Cuigezhuang', set(['Cuigezhuang'])),
#  ('Cultivation', set(['Hall of Mental Cultivation'])),
#  ('Cun',
#   set(['Bei Hegezhuang Cun',
#        'Cangtou Cun',
#        'Gaoguzhuang Cun',
#        'Louzizhuang Cun',
#        'Lu Xinzhuang Cun',
#        'Qianxinzhuang Cun',
#        'SanchaHe Cun',
#        'Shiyuan Cun',
#        'Shuangbutou Cun',
#        'Xiangyang Cun',
#        'Zhangjiawan Cun'])),
#  ('D',
#   set(['Beixinqiao Subway Line 5 Exit D',
#        'D',
#        'Exit D',
#        'Jiarun Garden Building D',
#        'Shunyi Station - Exit D'])),
#  ('D1', set(['Exit D1'])),
#  ('D2', set(['Exit D2'])),
#  ('DIN', set(['DIN'])),
#  ('DONGDAJIE', set(['ANDINGMEN DONGDAJIE'])),
#  ('Dabaotai', set(['Dabaotai'])),
#  ('Dabeiwucun', set(['Dabeiwucun'])),
#  ('Dachengzi', set(['Dachengzi'])),
#  ('Dada', set(['Dada'])),
#  ('Dadicun', set(['Dadicun'])),
#  ('Dagexiang', set(['Dagexiang'])),
#  ('Dagoba', set(['The White Dagoba'])),
#  ('Daguanying', set(['Daguanying'])),
#  ('Dahongmen', set(['Dahongmen'])),
#  ('Dahuichang', set(['Dahuichang'])),
#  ('Daije', set(['Wu Si Daije'])),
#  ('Dajiaoting', set(['Dajiaoting'])),
#  ('Dajing', set(['Dajing'])),
#  ('Dalian', set(['Bank of Dalian'])),
#  ('Dalianpo', set(['Dalianpo'])),
#  ('Daludian', set(['Daludian'])),
#  ('Dan', set(['Xi Dan'])),
#  ('Dao', set(['Cui Fu Jia Dao', 'Da Xue Jia Dao'])),
#  ('Daotian', set(['Daotian'])),
#  ('Daoxianghulu', set(['Daoxianghulu'])),
#  ('Dapangcun', set(['Dapangcun'])),
#  ('Dasha', set(['Ziming Dasha'])),
#  ('Dashilan', set(['Dashilan'])),
#  ('Dashimencun', set(['Dashimencun'])),
#  ('Dashiwo', set(['Dashiwo'])),
#  ('Datai', set(['Datai'])),
#  ('Dawanglu', set(['Dawanglu'])),
#  ('Dawayao', set(['Dawayao'])),
#  ('Dawuji', set(['Dawuji'])),
#  ('Daxinzhuangcun', set(['Daxinzhuangcun'])),
#  ('Dayuzicun', set(['Dayuzicun'])),
#  ('Dazhongsi', set(['Carrefour Dazhongsi', 'Dazhongsi'])),
#  ('Deal', set(['Deal'])),
#  ('Dealer', set(['Beijing JBW Car Dealer'])),
#  ('Decathlon', set(['Decathlon'])),
#  ('Deer', set(['Deer'])),
#  ('Delice', set(['Delice'])),
#  ('Delirium', set(['Delirium'])),
#  ('Dengshikou', set(['Dengshikou'])),
#  ('Denmark', set(['Embassy of Denmark'])),
#  ('Depot',
#   set(['Beijing Depot',
#        'Beijing EMU Depot',
#        'Beijing West Depot',
#        'Pingxifu Depot'])),
#  ('Deshengmen',
#   set(['877 bus  to Deshengmen', 'Holiday Inn Beijing Deshengmen'])),
#  ('Design', set(['Academy of Arts and Design'])),
#  ('Dian', set(['Chang Dian'])),
#  ('Dichan', set(['Zhonglian Dichan'])),
#  ('Digezhuangcun', set(['Digezhuangcun'])),
#  ('Dingjiazhuangcun', set(['Dingjiazhuangcun'])),
#  ('Dingzhuangcun', set(['Dingzhuangcun'])),
#  ('District',
#   set(['798 Art District',
#        'Anci District',
#        'Beijing 798 Art District',
#        'Changping District',
#        'Chaoyang District',
#        'Daxing District',
#        'Dongcheng District',
#        'Dongzhimen District',
#        'Fangshan District',
#        'Fengtai District',
#        'Guangyang District',
#        'Haidian District',
#        'Huairou District',
#        'Jiangtaixiang District',
#        'Jiuxianqiao District',
#        'Lize Business District',
#        'Mentougou District',
#        'Miyun District',
#        'Pinggu District',
#        'Shijingshan District',
#        'Shunyi District',
#        'Tongzhou District',
#        'Wanping District',
#        'Wuqing District',
#        'Xicheng District',
#        'Zhongguancun District'])),
#  ('Division', set(['Beijing Second Intermediate Court Second Division'])),
#  ('Dolce', set(['Vivi Dolce'])),
#  ('DongBaLiZhuang', set(['CITIC Bank DongBaLiZhuang'])),
#  ('DongZhiMen', set(['DongZhiMen'])),
#  ('Dongcheng', set(['Dongcheng'])),
#  ('Dongdajie', set(['Huilongguang Dongdajie'])),
#  ('Dongdan', set(['Dongdan'])),
#  ('Dongdaqiao', set(['Dongdaqiao'])),
#  ('Dongertiao', set(['Ritan Dongertiao'])),
#  ('Dongfengcun', set(['Dongfengcun'])),
#  ('Dongfushouli', set(['Dongfushouli'])),
#  ('Dongguan', set(['Changping Dongguan'])),
#  ('Dongguantou', set(['Dongguantou'])),
#  ('Donghuluyucun', set(['Donghuluyucun'])),
#  ('Donghuqu', set(['Donghuqu'])),
#  ('Dongjie', set(['Huixin Dongjie', 'Yinghuayuan Dongjie'])),
#  ('Donglaishun', set(['Donglaishun'])),
#  ('Donglu', set(['Beichen Donglu', "Jian'an Donglu", 'Madian Donglu'])),
#  ('Dongsi', set(['Dongsi'])),
#  ('Dongsishitiao', set(['Dongsishitiao'])),
#  ('Dongxiayuan', set(['Dongxiayuan'])),
#  ('Dongxingyuancun', set(['Dongxingyuancun'])),
#  ('Dongyaocun', set(['Dongyaocun'])),
#  ('Dongyitiao', set(['Ritan Dongyitiao'])),
#  ('Dongyu', set(['Dongyu'])),
#  ('Dongzhimen', set(['Dongzhimen'])),
#  ('Dongzhuang', set(['Xiao Dongzhuang'])),
#  ('Donnalds', set(['Mc Donnalds'])),
#  ('Donuts', set(['Dunkin Donuts'])),
#  ('Dormitory', set(['16th Dormitory', '2nd Dormitory'])),
#  ('Dorms', set(['DaYunCun, Dorms'])),
#  ('Doudian', set(['Doudian'])),
#  ('Dreamport', set(['China Resources Dreamport'])),
#  ('Duck',
#   set(['Deyuan Roasted Duck',
#        'Peking Duck',
#        'Quanjude Beijing Duck',
#        'Rubber Duck'])),
#  ('Duct', set(['Quanjude Roast Duct'])),
#  ('Duicun', set(['Shagu Duicun'])),
#  ('Dumplings', set(['Dumplings'])),
#  ('Duozicun', set(['Duozicun'])),
#  ('Dynasty', set(['9th Dynasty', 'Wall Park of Ming Dynasty'])),
#  ('E',
#   set(['Exit E',
#        'Hujialou Station Line 6 & 10 E',
#        'N 3rd Ring Rd. E',
#        'N 4th Ring Rd. E'])),
#  ('E1', set(['Exit E1'])),
#  ('Earth', set(['Temple of Earth'])),
#  ('East',
#   set(['BaoSheng East',
#        'Beijing East',
#        'Beijing Station East',
#        'Datunlu East',
#        'Hepingli East',
#        'JianWai SOHO East',
#        'Jiaomen East',
#        'Liuliqiao East',
#        'Madian Bridge East',
#        'Qianhai East',
#        'Sanlihe East',
#        'Sihui East',
#        "Tian'anmen East",
#        'Wangjing East',
#        'Xihai East',
#        'Zhuozhou East'])),
#  ('Economics',
#   set(['Central University of Finance and Economics',
#        'University of International Business and Economics'])),
#  ('Education', set(['Building of Continuous Education'])),
#  ('Elegance', set(['Mountain of Accumulated Elegance'])),
#  ('Elements', set(['Elements'])),
#  ('Eleven', set(['7 Eleven'])),
#  ('Embassy',
#   set(['British Embassy',
#        'Malaysian Embassy',
#        'Royal Thai Embassy',
#        'Russian Embassy'])),
#  ('Eminence', set(['Hall of Military Eminence'])),
#  ('Energy', set(['China Institute of Atomic Energy'])),
#  ('Engineering', set(['School of Civil Engineering'])),
#  ('Entrance',
#   set(['East Entrance',
#        'Forbidden City Entrance',
#        'Jingshan West Entrance',
#        'South Entrance'])),
#  ('Entry', set(['Entry'])),
#  ('Erdaohe', set(['Erdaohe'])),
#  ('Erligou', set(['Erligou'])),
#  ('Ertiao',
#   set(['Banqiao Ertiao',
#        'Caochang Ertiao',
#        'Changxiang Ertiao',
#        'Heng Ertiao',
#        'Langfang Ertiao',
#        'Liupukang Ertiao'])),
#  ('Exhibition', set(['Visitor Centre Exhibition'])),
#  ('Exit',
#   set(['Exit',
#        'North-East Exit',
#        'North-West Exit',
#        'South-East Exit',
#        'South-West Exit'])),
#  ('Expo', set(['Garden Expo'])),
#  ('Express',
#   set(['Beijing Subway Airport Express',
#        'Beijing WangJing Holiday Inn Express'])),
#  ('Expressway',
#   set(['Beijing -Chengde Expressway',
#        'Beijing-Harbin Expressway',
#        u'Beijing–Lhasa Expressway',
#        'G1 Jingha Expressway',
#        u'G1N Beijing–Qinhuangdao Expressway',
#        'G2 Jinghu Expressway',
#        'G3 Jingtai Expressway',
#        "G4 Jinggang'ao Expressway",
#        'G45 Daguang Expressway',
#        'G6 Jingzang Expressway',
#        'G7 Jingxin Expressway',
#        "Jinggang'ao Expressway",
#        'Jinghu Expressway',
#        'Jingjintang Expressway',
#        'Jingshi Expressway',
#        'Jingtong Expressway',
#        'Jingxin Expressway',
#        'Jingzhang Expressway',
#        'Side Road of Jing-shi Expressway'])),
#  ('Expressways', set(['NTHS Expressways'])),
#  ('F', set(['Exit F'])),
#  ('FENGBO', set(['FENGBO'])),
#  ('Fa', set(['Chao Shi Fa'])),
#  ('Facun', set(['Beihuo Facun', 'Nanhuo Facun'])),
#  ('Fangezhuang', set(['Fangezhuang'])),
#  ('Fangshan', set(['Fangshan'])),
#  ('Fangzhuang', set(['Fangzhuang'])),
#  ('Farm', set(['Guanting Wind Power Farm'])),
#  ('Fatou', set(['Fatou'])),
#  ('Fatoucun', set(['Fatoucun'])),
#  ('Fatoudongli', set(['Fatoudongli'])),
#  ('Fen', set(['Tong Jia Fen'])),
#  ('Fengbo', set(['Fengbo'])),
#  ('Fengtai', set(['Boundary Dongcheng - Fengtai', 'Fengtai'])),
#  ('Fengtaidongdajie', set(['Fengtaidongdajie'])),
#  ('Fengtainanlu', set(['Fengtainanlu'])),
#  ('Fengtaizhan', set(['Fengtaizhan'])),
#  ('Fenzhongsi', set(['Fenzhongsi'])),
#  ('Field',
#   set(['Baseball Field',
#        'Fengtai Sports Center Softball Field',
#        'Small Football Field',
#        'Sporting Field'])),
#  ('Finance', set(['Museum of Global Finance'])),
#  ('Flowers', set(['Labyrinth of Thousands of Flowers'])),
#  ('Food', set(['Beer Garden + Food', "Wiggly Jiggly's Cafe&Bar & Food"])),
#  ('Force', set(['Pits of canon fire of Japanese Force'])),
#  ('Forest', set(['Century Forest'])),
#  ('Fortinet', set(['Fortinet'])),
#  ('Fortress', set(['Tuan Cheng Fortress', 'Zhenbian Fortress'])),
#  ('Fountain', set(['Great Fountain'])),
#  ('Fountains', set(['Water reservior for Fountains'])),
#  ('France', set(['Embassy of France'])),
#  ('Fresh', set(['Great Wall Fresh', 'Mai Fresh'])),
#  ('Fu', set(['Qin Tang Fu'])),
#  ('FuAnXiLu', set(['FuAnXiLu'])),
#  ('FuTongXiDaJie', set(['FuTongXiDaJie'])),
#  ('Fuchengmen', set(['Fuchengmen'])),
#  ('Fuhaocun', set(['Fuhaocun'])),
#  ('Fun', set(['Din Tai Fun'])),
#  ('Fung', set(['Din Tai Fung'])),
#  ('Futong', set(['Futong'])),
#  ('Fuxingmen', set(['Fuxingmen'])),
#  ('Fuyuan', set(['JinJiang Fuyuan'])),
#  ('G', set(['Exit G'])),
#  ('GONGHUACHENG', set(['GONGHUACHENG'])),
#  ('Gallery',
#   set(['1x3 Gallery',
#        'Polar Bear Gallery',
#        'Tabula Rasa Gallery',
#        'The First Sound Gallery'])),
#  ('Gangzicun', set(['Gangzicun'])),
#  ('Ganjiakou', set(['Ganjiakou'])),
#  ('Gaobeidian', set(['Gaobeidian'])),
#  ('Gaojiayuan', set(['Gaojiayuan'])),
#  ('Garden',
#   set(['Bear Garden',
#        'Beijing Botanical Garden',
#        'Beijing Roman Garden',
#        'Central Garden',
#        'Fragrant Garden',
#        'Grand View Garden',
#        'Hundred-Flower Garden',
#        'Imperial Garden',
#        'Jiarun Garden',
#        'Lishui Garden',
#        'Shimao Olive Garden'])),
#  ('Garret', set(['Garret'])),
#  ('Gate',
#   set(['Chengzhen Gate',
#        'East Gate',
#        'East Glorious Gate',
#        'East Heavenly Gate',
#        'Favorably Govern Gate',
#        'Guangli Gate',
#        'Main Gate',
#        'Majestic Gate',
#        'Meridian Gate',
#        'North Gate',
#        'North Heavenly Gate',
#        'Northeast Gate',
#        'Northwest Gate',
#        'Old Summer Palace East Gate',
#        'Shunzhi Gate',
#        'South Gate',
#        'Taiyuan Gate',
#        'The Gate',
#        'The Old Gate',
#        'West Gate',
#        'West Glorious Gate',
#        'West Heavenly Gate',
#        'Yongding Gate',
#        'Yuyuantan Park East Gate'])),
#  ('Gates', set(['The Three Gates'])),
#  ('Geology', set(['China Institute of Geology'])),
#  ('Gequcun', set(['Gequcun'])),
#  ('Germany', set(['Embassy of Germany'])),
#  ('Glory', set(['Hall of Literary Glory'])),
#  ('Goddess', set(['Red Leaves Goddess'])),
#  ('GongYuan', set(['WangJing GongYuan'])),
#  ('Gonghuacheng', set(['Gonghuacheng'])),
#  ('Gongrentiyuchang', set(['S. Gongrentiyuchang'])),
#  ('Gongsan', set(['Shimao Gongsan'])),
#  ('Gongyixiqiao', set(['Gongyixiqiao'])),
#  ('Gongzhufen', set(['Gongzhufen'])),
#  ('Gongzhufu', set(['Heijing Gongzhufu'])),
#  ('Gongzuoshi', set(['Meifa Gongzuoshi'])),
#  ('Gourmet', set(['April Gourmet'])),
#  ('Green', set(['Olympic Green'])),
#  ('Grid)',
#   set(['CEPRI China Electric Power Research Institute (State Grid)'])),
#  ('Ground',
#   set(['East Sports Ground', 'West Sports Ground', 'Zijing Sports Ground'])),
#  ("Gu'an", set(["Gu'an"])),
#  ('Guachangcun', set(['Guachangcun'])),
#  ("Guang'anmennei", set(["Guang'anmennei"])),
#  ('Guangqumennei', set(['Guangqumennei'])),
#  ('Guangqumenwai', set(['Guangqumenwai'])),
#  ('Guangximen', set(['Guangximen'])),
#  ('Guangyangcheng', set(['Guangyangcheng'])),
#  ('Guantoucun', set(['Guantoucun'])),
#  ('Guanzhuang', set(['Guanzhuang'])),
#  ('Guarden', set(['Chinese Rose Guarden'])),
#  ('Gucheng', set(['Gucheng'])),
#  ('Guesthouse',
#   set(['Beijing Huanghuacheng Water Great Wall Derunju Guesthouse',
#        'Diaoyutai National Guesthouse'])),
#  ('Guloudajie', set(['Guloudajie'])),
#  ('GuoAocun', set(['GuoAocun'])),
#  ('Guogongzhuang', set(['Guogongzhuang'])),
#  ('Guojiawu', set(['Guojiawu'])),
#  ('Guomao', set(['Guomao'])),
#  ('Guoyuan', set(['Guoyuan'])),
#  ('Guozhuangzi', set(['Guozhuangzi'])),
#  ('Gushankou', set(['Gushankou'])),
#  ('Gymnasium',
#   set(['Badminton Gymnasium',
#        'East Gymnasium',
#        'West Gymnasium',
#        "Worker's Gymnasium"])),
#  (u'Gérard', set([u'Chez Gérard'])),
#  ('H', set(['Exit H'])),
#  ('H&M', set(['H&M'])),
#  ('HOSPICE', set(['HOSPICE'])),
#  ('HOTEL', set(['ASIA PACIFIC GARDEN HOTEL'])),
#  ('HOUSHAYU', set(['HOUSHAYU'])),
#  ('HS', set(['Western Academy of Beijing HS'])),
#  ('HUALIKAN', set(['HUALIKAN'])),
#  ('HUILONGGUAN', set(['HUILONGGUAN'])),
#  ('HUOYING', set(['HUOYING'])),
#  ('Habor', set(['Solana Blue Habor'])),
#  ('Haihe)', set(['Yongding basin (Haihe)'])),
#  ('Hall',
#   set(['Architecture Hall',
#        'Beijing Planning Exhibition Hall',
#        'Chairman Mao Memorial Hall',
#        'Dining Hall',
#        'East Hall',
#        'East Warm Hall',
#        'Heavenly King Hall',
#        'Hunan Guild Hall',
#        'Mong Man-wai Concert Hall',
#        'No.1 Dining Hall',
#        'No.2 Dining Hall',
#        'No.3 Dining Hall',
#        'Residential Hall',
#        'Shooting Hall',
#        'Staff Residential Hall',
#        'Swimming Hall',
#        'Temple Main Entrance Hall',
#        'West Warm Hall',
#        'ZaoJian Hall',
#        'Zheng Jue Hall'])),
#  ('Hancunhe', set(['Hancunhe'])),
#  ('Hans', set(['Golden Hans'])),
#  ('Haojiafu', set(['Haojiafu'])),
#  ('Happiness', set(['Extreme Happiness'])),
#  ('HappyValley', set(['HappyValley'])),
#  ('Harmony',
#   set(['Gate of Harmony',
#        'Gate of Prosperous Harmony',
#        'Gate of Supreme Harmony',
#        'Hall of Central Harmony',
#        'Hall of Preserving Harmony',
#        'Hall of Supreme Harmony'])),
#  ('Harvests',
#   set(['Altar of Earth and Harvests', 'Hall of Prayer for Good Harvests'])),
#  ('He', set(['Qingshui He', 'Sandu He'])),
#  ('Head', set(['Tiantai Mt Buddha Head'])),
#  ('Headquarter', set(['Lenovo China Headquarter'])),
#  ('Headquarters', set(['Bank of China Headquarters', 'CCTV Headquarters'])),
#  ('Health', set(['Parkway Health'])),
#  ('Heart', set(['Peaceful Heart'])),
#  ('Heaven',
#   set(['Hall of High Heaven',
#        'Imperial Hall of Heaven',
#        'Imperial Vault of Heaven',
#        'Temple of Heaven'])),
#  ('Hebei', set(['Border Beijing - Hebei', 'Hebei'])),
#  ('HeiQiao', set(['HeiQiao'])),
#  ('Heiqiaocun', set(['Heiqiaocun'])),
#  ('Henantai', set(['Henantai'])),
#  ('Hengjiezi', set(['Hengjiezi'])),
#  ('Hepinglibeijie', set(['Hepinglibeijie'])),
#  ('Hepingmen', set(['Hepingmen'])),
#  ('Hepingxiqiao', set(['Hepingxiqiao'])),
#  ('Heroes', set(['Monument of Heroes'])),
#  ('Hi-24', set(['Hi-24'])),
#  ('Highway',
#   set(['Beitai Highway',
#        'Fanqi Highway',
#        'Hongyan Highway',
#        'Huaichang Highway',
#        'Huaigeng Highway',
#        'Huaihuang Highway',
#        'HuoSha Highway',
#        'Jing Jia Highway',
#        'Jingjia Highway',
#        'Jingshen Highway',
#        'Shuinan Highway',
#        'Tianbei Highway'])),
#  ('Hill',
#   set(['Danzi Hill',
#        'Feng Hill',
#        'Fragrant Hill',
#        'Hui Hill',
#        'Long Hill',
#        'Longevity Hill',
#        'Monkey Hill',
#        'White Tower Hill'])),
#  ('Holic', set(['Coffee Holic'])),
#  ('Holiland', set(['Holiland'])),
#  ('Hollywood', set(['Hollywood'])),
#  ('Home)', set(['Bei Jing Ren Jia (Beijing Home)'])),
#  ('Hongliannanli', set(['Hongliannanli'])),
#  ('Hongmiao', set(['Hongmiao'])),
#  ('Hongqiao', set(['G133 Beijing South - Shanghai Hongqiao'])),
#  ('Hospital',
#   set(['BUPT Hospital',
#        'Beihang Hospital',
#        'Beijing Haidian Hospital',
#        'Beijing Huairou Hospital',
#        'Beijing Maternity Hospital',
#        'Beijing National Hospital',
#        'Beiya Hospital',
#        "Capital Institute of Pediatrics Affiliated Children's Hospital",
#        'Dongzhimen Hospital',
#        'HarMoni Care Hospital',
#        'Hospital',
#        'Jiugong Hospital',
#        'Kangyide Hospital',
#        'Oasis International Hospital',
#        'Peking Union Medical College Hospital',
#        'Peking University First Hospital',
#        'Qinghua Changyi Hospital',
#        'Tsinghua University Hospital',
#        'University Hospital',
#        'Wangjing Hospital',
#        'Yizhuang Hospital'])),
#  ('Hostel',
#   set(['Beijing Lama Temple Youth Hostel',
#        'Beijing P.LOFT Youth Hostel',
#        'Far East International Youth Hostel',
#        'Golden Pineapple International Youth Hostel',
#        'Sanlitun International Hostel',
#        'Sanlitun Youth Hostel'])),
#  ('Hotel',
#   set(['161 Hotel',
#        'Badaling Hotel',
#        'Beijing Double Happiness Courtyard Hotel',
#        'Beijing Exhibition Center Hotel',
#        'Beijing Friendship Hotel',
#        'Beijing Hotel',
#        'Beijing Judges Education Instutite Hotel',
#        'Beijing Shijingshan HNA Grand Hotel',
#        'Beijing Sicily Hotel',
#        'Beijing WenJin Hotel',
#        'Cathay View Holiday Hotel',
#        'Chang An Grand Hotel',
#        'China World Hotel',
#        'Fragrant Hill Hotel',
#        'Grand Skylight Catic Hotel',
#        'Home Holiday Hotel',
#        'Jinglun Hotel',
#        'Jintai Hotel',
#        'King Parkview Hotel',
#        'Langham Hotel',
#        'Lanxi Hotel',
#        'Marco Polo Parkside Hotel',
#        'Nacional Jade Hotel',
#        'North Star Continental Grand Hotel',
#        'Pangu Seven Star Hotel',
#        'Pullman Hotel',
#        'Qianmen Jianguo Hotel',
#        'Red Hotel',
#        'Ritan Hotel',
#        'Shangri-La Hotel',
#        'Sunrise East Kempinski Hotel',
#        'Sunshine Hotel',
#        'Tongliantaihe Hotel',
#        'Vision Hotel',
#        'Xiamen Commerce Hotel',
#        'Xijiao Hotel',
# ...
#  ('Xiejie', set(['Baimi Xiejie'])),
#  ('Xifushouli', set(['Xifushouli'])),
#  ('Xiheyan', set(['Chongwenmen Xiheyan'])),
#  ('Xihongmen', set(['Xihongmen'])),
#  ('Xihuangchenggen', set(['S. Xihuangchenggen'])),
#  ('Xijie', set(['Huixin Xijie', 'Rongjing Xijie'])),
#  ('Xiju', set(['Xiju'])),
#  ('Xilu', set(['Changwa Xilu'])),
#  ('Xiluoyuan', set(['Xiluoyuan'])),
#  ('Xinglongzhuangcun', set(['Xinglongzhuangcun'])),
#  ('Xingong', set(['Xingong'])),
#  ('Xinhecun', set(['Xinhecun'])),
#  ('Xinjiekou', set(['Xinjiekou'])),
#  ('Xintiandi', set(['Huguosi Xintiandi'])),
#  ('Xinying', set(['Xinying'])),
#  ('Xinyingcun', set(['Xinyingcun'])),
#  ('Xinzhuang', set(['Ding Xinzhuang'])),
#  ('Xinzhuangcun', set(['Lang Xinzhuangcun'])),
#  ('Xinzhuangzicun', set(['Xinzhuangzicun'])),
#  ('Xiqu', set(['125 Wangjing Huayuan Xiqu'])),
#  ('Xisancu', set(['Xisancu'])),
#  ('Xishankou',
#   set(['Changping Xishankou', "Subway CP: Xi'erqi => Changping Xishankou"])),
#  ('Xishaoqu', set(['Xishaoqu'])),
#  ('Xisi', set(['Xisi'])),
#  ('Xitieying', set(['Xitieying'])),
#  ('Xitucheng', set(['Xitucheng'])),
#  ('Xiwacun', set(['Xiwacun'])),
#  ('Xixiang', set(['Huguosi Xixiang'])),
#  ('Xixiaokou', set(['Xixiaokou'])),
#  ('Xixingyuancun', set(['Xixingyuancun'])),
#  ('Xiyan', set(['Houhai Xiyan'])),
#  ('Xiyuan', set(['Xiyuan'])),
#  ('Xizhihe', set(['Xizhihe'])),
#  ('Xizhimen', set(['Xizhimen'])),
#  ('Xuanwumen', set(['Xuanwumen'])),
#  ('Xuzhuangcun', set(['Xuzhuangcun'])),
#  ('Yanchi', set(['Yanchi'])),
#  ('Yancun', set(['Yancun'])),
#  ('Yang', set(['Gallery Yang'])),
#  ('Yangfang', set(['Yangfang'])),
#  ('Yangmeizhu', set(['Yangmeizhu'])),
#  ('Yangtai', set(['Yangtai'])),
#  ('Yangtiancun', set(['Yangtiancun'])),
#  ('Yanhecheng', set(['Yanhecheng'])),
#  ('Yanjiao', set(['Yanjiao'])),
#  ('Yanwo', set(['Yanwo'])),
#  ('Yi', set(['Burial vault of Tomb of Tian Yi', 'Tomb of Tian Yi'])),
#  ('Yihezhuang', set(['Yihezhuang'])),
#  ('Yindingqiao', set(['Yindingqiao'])),
#  ('Yindongcun', set(['Yindongcun'])),
#  ('Yingbi', set(['Yingbi'])),
#  ('Yingsi', set(['Yingsi'])),
#  ('Yingtao', set(['Yingtao'])),
#  ('Yinyeling', set(['Yinyeling'])),
#  ('Yitiao', set(['Liupukang Yitiao'])),
#  ('Yizhuang', set(['Yizhuang'])),
#  ('Yizhuangqiao', set(['Yizhuangqiao'])),
#  ('Yongandongli', set(['Yongandongli'])),
#  ('Yonganli', set(['Yonganli'])),
#  ('Yongdingmenwai', set(['Yongdingmenwai'])),
#  ('Yongfeng', set(['Yongfeng'])),
#  ('Yongle', set(['Yongle'])),
#  ('Yongtaizhuang', set(['Yongtaizhuang'])),
#  ('Yoshinoya', set(['Yoshinoya'])),
#  ("You'anmen", set(["You'anmen"])),
#  ('Youanmenwai', set(['Youanmenwai'])),
#  ('Yuan',
#   set(['Bai Jia Da Yuan',
#        'Guan Fang Da Yuan',
#        'Jin Chun Yuan',
#        'Qingshang Yuan',
#        'Xi Yuan',
#        'Zhao Lan Yuan'])),
#  ('Yuancun', set(['Beiyao Yuancun', 'Nanyao Yuancun'])),
#  ('Yuandala', set(['Yuandala'])),
#  ('Yucun', set(['Shihu Yucun', 'Xishui Yucun'])),
#  ('Yunjusi', set(['Yunjusi'])),
#  ('Yuquanlu', set(['Yuquanlu'])),
#  ('Yushuzhuang', set(['Yushuzhuang'])),
#  ('Yuxiandu', set(['Yuxiandu'])),
#  ('Yuxin', set(['Yuxin'])),
#  ('Yuzhilu', set(['Yuzhilu'])),
#  ('ZAOYUAN', set(['ZAOYUAN'])),
#  ('ZARA', set(['ZARA'])),
#  ('ZHUXINZHUANG', set(['ZHUXINZHUANG'])),
#  ('Zaixiangzhuangcun', set(['Zaixiangzhuangcun'])),
#  ('Zamo', set(['Zamo'])),
#  ('Zaoying', set(['Zaoying'])),
#  ('Zaoyuan', set(['Zaoyuan'])),
#  ('Zara', set(['Zara'])),
#  ('Zhai',
#   set(['Jing Lian Zhai', 'Jing Zhai', 'Ming Zhai', 'Qiang Zhai', 'Xin Zhai'])),
#  ('Zhaitang', set(['Zhaitang'])),
#  ('ZhanWangFen', set(['ZhanWangFen'])),
#  ('Zhangfang', set(['Zhangfang'])),
#  ('Zhangguozhuang', set(['Zhangguozhuang'])),
#  ('Zhangjiadian', set(['Zhangjiadian'])),
#  ('Zhangwancun', set(['Zhangwancun'])),
#  ('Zhangxin', set(['Zhangxin'])),
#  ('Zhangzizhonglu', set(['Zhangzizhonglu'])),
#  ('Zhenbiancheng', set(['Zhenbiancheng'])),
#  ('Zhengjuejiadao', set(['Zhengjuejiadao'])),
#  ('Zhengyangmen', set(['Archery Tower of Zhengyangmen', 'Zhengyangmen'])),
#  ('Zhichunli', set(['Zhichunli'])),
#  ('Zhichunlu', set(['Zhichunlu'])),
#  ('ZhongGuanCun', set(['Hampson School, ZhongGuanCun'])),
#  ('Zhongfule', set(['Zhongfule'])),
#  ('Zhongguancun', set(['Zhongguancun'])),
#  ('Zhongjingjidou', set(['Zhongjingjidou'])),
#  ('Zhonglu',
#   set(['Rhonghua Zhonglu',
#        'Ronghua Nanlu; Rhonghua Zhonglu',
#        'Xihuan Zhonglu'])),
#  ('Zhongmaojiawan', set(['Zhongmaojiawan'])),
#  ('Zhongnanhai', set(['Zhongnanhai'])),
#  ('Zhongzhuangcun', set(['Zhongzhuangcun'])),
#  ('Zhoukoudian', set(['Peking Man Site at Zhoukoudian', 'Zhoukoudian'])),
#  ('ZhuFang', set(['ZhuFang'])),
#  ('Zhuangcun',
#   set(['Baxian Zhuangcun',
#        'Daxin Zhuangcun',
#        'Houxin Zhuangcun',
#        'Langge Zhuangcun',
#        'Liangge Zhuangcun',
#        'Lige Zhuangcun',
#        'Mage Zhuangcun',
#        'Qishan Zhuangcun',
#        'Yinge Zhuangcun',
#        'Zaolin Zhuangcun'])),
#  ('Zhuanghua`yu', set(['Zhuanghua`yu'])),
#  ('Zhuozhou', set(['Zhuozhou'])),
#  ('Zhushikou', set(['Zhushikou'])),
#  ('Zhuxinzhuang', set(['Zhuxinzhuang'])),
#  (u'Zhuàngdàokou', set([u'Zhuàngdàokou'])),
#  ('Zi', set(['Wang Pang Zi'])),
#  ('Zoo', set(['Beijing Zoo', 'Blue Zoo'])),
#  ('Zpark', set(['Zpark'])),
#  ('alleys', set(['Fudong 1st alleys'])),
#  ('animals',
#   set(['American animals', 'Australian animals', 'Noctumal animals'])),
#  ('apartment', set(['Building 37 - International student apartment'])),
#  ('area', set(['Canal to Olympic area'])),
#  ('bak', set(['Daily bak'])),
#  ('bank', set(['China Merchants bank'])),
#  (u'bar', set(['Slow boat bar', u'backyard café & bar'])),
#  ('basin', set(['Chaobai basin'])),
#  ('best', set(["Pantry's best"])),
#  ('bistro', set(['Nosh Indian bistro'])),
#  ('bnb', set(['air bnb'])),
#  ('bookstore', set(['Paradise Time Travel bookstore', 'dorm bookstore'])),
#  ('brewery', set(['Slow boat brewery'])),
#  ('bridge', set(['Guang`anmen bridge', 'Tianningsi bridge'])),
#  ('bridge)', set(['Home inn (Suzhou bridge)'])),
#  ('brunch', set(['Cafe Groove - coffee & brunch'])),
#  ('building', set(['Laboratory building', 'Main building'])),
#  ('buildings', set(['Linked hybrid buildings'])),
#  ('c', set(['the mix c'])),
#  ('cafe',
#   set(['798 art cafe',
#        '85 degree cafe',
#        '85 degree daily cafe',
#        'Alley cafe',
#        'Tree gallery and cafe',
#        'vineyard cafe'])),
#  ('caffe', set(['Meow caffe'])),
#  (u'café', set([u'Friends café', u'Mc café'])),
#  ('caihonglu', set(['caihonglu'])),
#  ('cake', set(['Wedome cake'])),
#  ('camps', set(['99 camps'])),
#  ('canguan', set(['Ri chang canguan'])),
#  ('caochangdi', set(['caochangdi'])),
#  ('center',
#   set(['High school swimming center', 'Tunbao center', 'Yabao center'])),
#  ('centre', set(['Body Strong Fitness centre', 'UK visa application centre'])),
#  ('chenggezhuang', set(['chenggezhuang'])),
#  ('chicken', set(['Kentucky Fried chicken'])),
#  ('china', set(['National museum of china'])),
#  ('cinema', set(['cinema'])),
#  ('club', set(['East shore jazz club'])),
#  ('coffee', set(['Tigris coffee', 'voyage coffee'])),
#  ('community',
#   set(['Lehongyuan community',
#        'Lingxiu Huigu A community',
#        'Lingxiu Huigu B community',
#        'Lingxiu Huigu D community',
#        'Tiantong Beiyuan 1st community',
#        'Tiantong Beiyuan 2nd community',
#        'Yujiayuan No.1 community',
#        'Zhuxinzhuang North community',
#        'Zhuxinzhuang community',
#        'lingxiu Huigu 1st community'])),
#  ('construction)',
#   set(['Beijing Daxing International Airport (construction)'])),
#  ('core', set(['beauty hair core'])),
#  ('court', set(['Badminton court'])),
#  ('cuisin', set(['canton cuisin'])),
#  ('dashanzilukoudong', set(['dashanzilukoudong'])),
#  ('di', set(['cao chang di'])),
#  ('dongfengqiaodong', set(['dongfengqiaodong'])),
#  ('donglu', set(['Wenhuayuan donglu'])),
#  ('dragon', set(['Beijing saga youth hostel. Happy dragon'])),
#  (u'déjeuner)', set([u'wudaoku (quartier étudiant/pause déjeuner)'])),
#  ('east', set(['east'])),
#  ('eleven', set(['seven eleven'])),
#  ('entry)', set(['ghost street (entry)'])),
#  ('equipment', set(['Beijing photography equipment'])),
#  ('erlongluxijie', set(['erlongluxijie'])),
#  ('erun360.com', set(['erun360.com'])),
#  ('exchange', set(['money exchange'])),
#  ('expressway', set(['Jingtai expressway'])),
#  ('farm', set(['Super farm'])),
#  ('field', set(['High school soccer field'])),
#  ('fine', set(['beijing fine'])),
#  ('flore', set(['Cafe de flore'])),
#  ('food', set(['Ghost street food', 'Very good local food'])),
#  ('friend', set(['friend'])),
#  ('fung', set(['Dumpling restaurant din tai fung'])),
#  ('gallery', set(['intelligentsia gallery'])),
#  ('gao', set(['nan gao'])),
#  ('garden', set(['Zhongshan garden'])),
#  ('gate', set(['Beijing zoo gate', 'Northwest gate'])),
#  ('gongyuan', set(['wangjing gongyuan'])),
#  ('gym', set(['High school gym'])),
#  ('haidilao', set(['haidilao'])),
#  ('hall', set(['ticket office clock exhibition hall'])),
#  ('here', set(['Come here'])),
#  ('highway',
#   set(['Huaihuang highway', 'Yangyan highway', 'Zhonggao highway'])),
#  ('history', set(['Museum of natural history'])),
#  ('home', set(['April Gourmet - The closest place to home'])),
#  ('hospital', set(['Fuhua hospital'])),
#  ('hostel', set(['Beijing jade youth hostel'])),
#  ('hotel',
#   set(['Orange hotel',
#        'Shang Yuan hotel',
#        'green tree inn hebei langfang development zone convention and exhibition center business hotel',
#        'xi yuan hotel'])),
#  ('hotpot', set(['seafood hotpot'])),
#  ('house', set(['ball house', 'green house'])),
#  ('huijing', set(['Tian hai huijing'])),
#  ('hutong',
#   set(['Daxi hutong', 'No.13 San yan jing hutong', 'buxiangzi hutong'])),
#  ('info', set(['tourist info'])),
#  ('inn', set(['home inn'])),
#  ('international', set(['Ritan international'])),
#  ('jangumen', set(['IBIS jangumen'])),
#  ('ji', set(['kao rou ji'])),
#  ('jiangtailukoubei', set(['jiangtailukoubei'])),
#  ('jie', set(['Liangshidian jie', 'qiubao shi jie'])),
#  ('jiuxianqiao', set(['jiuxianqiao'])),
#  ('jours', set(['Tous les jours'])),
#  ('kidsland', set(['kidsland'])),
#  ('la', set(['Pho la la'])),
#  ('lab', set(['zajia lab'])),
#  ('library', set(['High school library'])),
#  ('liutijihutong', set(['liutijihutong'])),
#  ('location', set(['Heyuan hostel actual location'])),
#  ('lu', set(['Anyuan lu', 'Aotizhong lu'])),
#  ('mall', set(['Jingbei shopping mall', 'grand pacific mall'])),
#  (u'mar', set([u'caracóis do mar'])),
#  ('market',
#   set(['Jingshen seafood market',
#        'Tianyi wholesale market',
#        'Xiayuan market',
#        'fair & food market'])),
#  ('mikvah', set(['Chabad school and mikvah'])),
#  ('ml', set(['400 ml'])),
#  ('mo', set(['na mo'])),
#  ('mountain', set(['Luotuo shan mountain'])),
#  ('museum', set(['CAFA museum', 'red brick art museum'])),
#  ('nanlu', set(['Ronghua nanlu'])),
#  ('noodles',
#   set(['Baochao noodles',
#        'Master Kong private beef noodles',
#        'lao beijing noodles',
#        'lao noodles'])),
#  ('north', set(['Qingchun road north', 'Yujiayuan north'])),
#  ('office', set(['ticket office'])),
#  ('orioles', set(['The hall for listening to orioles'])),
#  ('pagoda', set(['Boya pagoda'])),
#  ('pancake', set(['Awesome chinese pancake'])),
#  ('park', set(['Chengnan park'])),
#  ('peak', set(['Censer peak'])),
#  ('people', set(['Shudu people'])),
#  ('ph', set(['Tongrentang ph'])),
#  ('pharmacy', set(['Heniantang pharmacy'])),
#  ('pizza', set(['Hutong pizza'])),
#  ('place', set(["Sophie's place"])),
#  ('police', set(['police'])),
#  ('porcelain)', set(['shard box (porcelain)'])),
#  ('port', set(['International flower port'])),
#  ('pub', set(['Pet pub'])),
#  ('publicity', set(['Institute of national publicity'])),
#  ('qianmen', set(['qianmen'])),
#  ('qinghe', set(['qinghe'])),
#  ('quanjude', set(['rest. quanjude'])),
#  ('railway', set(['Jingtong railway'])),
#  ('rain', set(['Red rain'])),
#  ('repair', set(['Shoe repair'])),
#  ('restaurant',
#   set(['Fantastic dumpling restaurant',
#        'Hatsune Japanese restaurant',
#        'Sijiminfu roast duck restaurant',
#        'Sunrise restaurant',
#        "xiaowang's home restaurant",
#        'xiayushan restaurant'])),
#  ('resturant', set(['Huadan resturant'])),
#  ('river', set(['Huaisha river', 'Qing river'])),
#  ('road',
#   set(['5th Ring road',
#        'An Li road',
#        'Aolin west road',
#        'Bachang road',
#        'Baima road',
#        'Beiyuan road',
#        'Datun road',
#        'Fumi road',
#        'Guangqu road',
#        'Guangqu side road',
#        'Huaichang road',
#        'Huaigeng side road',
#        'Huaihuang road',
#        'Huaiyang road',
#        'Kaikou road',
#        'Litang road',
#        'Qianqi road',
#        'Qiaoping road',
#        'Qing River road',
#        'Shimen East road',
#        'Taiguan road',
#        'Yanqihu west road',
#        'Yingbin road',
#        u'kēhuì road',
#        u'lìshuǐ bridge west road',
#        'muyan road',
#        'nine tree middle road',
#        u'zhōngdōng road'])),
#  ('roundabout', set(['Mutianyu roundabout'])),
#  ('sandaozhalanhutong', set(['sandaozhalanhutong'])),
#  ('school',
#   set(['Huairou Guangming primary school',
#        'Huairou No.1 middle school',
#        'Huairou No.1 primary school',
#        'Huairou No.2 middle school',
#        'Huairou No.3 middle school',
#        'Huairou No.3 primary school',
#        'Huairou No.4 primary school',
#        'Huairou No.5 middle school',
#        'Huairou No.5 primary school',
#        'Huairou No.6 primary school',
#        'Miyun No. 7 middle school',
#        'banbuqiao school'])),
#  ('section', set(['egypt embassy consulate section'])),
#  ('shop', set(['Gong cha ice tea shop'])),
#  ('shout', set(['flat baby sambo shout'])),
#  ('siheyuan', set(['Beijing 161 hotel behai siheyuan'])),
#  ('site', set(['The Fourth World Conference on women meeting site'])),
#  ('ski', set(['Shuttle to Nanshan ski'])),
#  ('sleep/host', set(['sleep/host'])),
#  ('soho', set(['central perk coffee shop chaoyangmenwai soho'])),
#  ('soon)', set(['GAOJIAYUAN(Open soon)', 'Gaojiayuan(Open soon)'])),
#  ('station',
#   set(['26km station',
#        'Bus station',
#        'Dongsheng police station',
#        'Gongzhufen station',
#        'Huairou bus station',
#        'Huairou railway station',
#        'Miyun long-distance bus station',
#        'Police station',
#        'QILIZHUANG station',
#        'Sihui bus tub station',
#        'Yuquanlu subway station',
#        'shell gas station'])),
#  ('stop',
#   set(['Airport shuttle baifang stop',
#        'Airport shuttle huilongguan East street stop',
#        'Airport shuttle longze stop',
#        'Airport shuttle shangdi stop',
#        'Airport shuttle tiantongxiyuan stop',
#        'Bus stop',
#        'airport shuttle huilongguan west street stop',
#        'airport shuttle wangyi stop'])),
#  ('store', set(['Beijing department store', 'Convenience store'])),
#  ('street',
#   set(['Fuqian street',
#        'Fuqian west street',
#        'Ghost street',
#        'Huai`an street',
#        'Huairou Beida street',
#        'Nanxinhua street',
#        'Shangye west street',
#        'Suzhou street',
#        'Xingfu street',
#        'Zhaofu street',
#        'mo shi kou street',
#        'taipingzhuang North street'])),
#  ('supermarket', set(['Zhou Zhou Service Area supermarket'])),
#  ('taproom', set(['peiping machine brewing taproom'])),
#  ('temple', set(['Hongluo temple', 'Shengquan temple'])),
#  ('tiger', set(['Siberian tiger'])),
#  ('time', set(['Lovely time'])),
#  ('toilet', set(['Public toilet'])),
#  ('tomb', set(['Siling tomb'])),
#  ('toutiao', set(['Jiaodaokoubei toutiao'])),
#  ('town',
#   set(['Huaibei town',
#        'Miaocheng town',
#        'Qiaozi town',
#        'Yangsong town',
#        'Yanqi town',
#        'korea town'])),
#  ('track', set(['28km station north track'])),
#  ('university',
#   set(['The affiliated high school of capital normal university'])),
#  ('used', set(['Pharmacy Dorit used'])),
#  ('wall',
#   set(['877 to badaling great wall', 'Entrance for old balading great wall'])),
#  ('wangcunyuan', set(['wangcunyuan'])),
#  ('wangyefen', set(['wangyefen'])),
#  ('xi', set(['nan gao xi'])),
#  ('xia`bu', set(['Xia`bu xia`bu'])),
#  ('xiang', set(['Defeng dong xiang'])),
#  ('xilu', set(['Wenhuayuan xilu'])),
#  ('yu', set(['Ganjian yu'])),
#  ('yuan', set(['Sheng yi yuan', 'Shuangxiugong yuan', 'tian ju yuan'])),
#  ('zhongxin', set(['Huairou xueguan zhongxin'])),
#  ('zishouyuan', set(['zishouyuan']))]

# %%
# 根据审查数据完善mapping
mapping = {
    'Str': 'Street',
    'St': 'Street',
    'street': 'Street',
    'Rd': 'Road',
    'road': 'Road',
    'Lu': 'Road',
    'lu': 'Road',
    'Bld': 'Buiding',
    'Bldg': 'Buiding'
}

# %% [markdown]
# #### 修正name:en并生成csv文件

# %%
OSM_PATH = "beijing_china.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

def update_name(name, mapping):
    """将地址名以mapping键值结尾修改为mapping对应的value"""
    name_to_be_fixed = mapping.keys()
    for word in name_to_be_fixed:
        if name.endswith(word):
            name = name.replace(word, mapping[word])
    return name

def fix_name(street_name, mapping):
    """匹配数据集中结尾可能不规范的地址名称，并进行更新"""
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            update_name(street_name, mapping)
            
def shape_tag(el, tag):
    """按SQL格式对一级tag标签进行处理"""
    tg = {
        'id'   : el.attrib['id'],
        'key'  : tag.attrib['k'],
        'value': tag.attrib['v'],
        'type' : 'regular'
    }
            
    if is_street_enname(tag):
        tg['value'] = fix_name(tag.attrib['v'], mapping)
        
    if LOWER_COLON.match(tg['key']):
        tg['type'], _, tg['key'] = tg['key'].partition(':')
        
    return tg

def shape_way_node(el, i, nd):
    """按SQL格式对way标签下的node进行处理"""
    return {
        'id'      : el.attrib['id'],
        'node_id' : nd.attrib['ref'],
        'position': i
    }

def shape_element(el, node_attr_fields = NODE_FIELDS, way_attr_fields = WAY_FIELDS):
    """Clean and shape node or way XML element to Python dict"""
    tags = [shape_tag(el,t) for t in el.iter('tag')]
    if el.tag == 'node':
        node_attribs = {f: el.attrib[f] for f in node_attr_fields}
        return {'node': node_attribs, 'node_tags': tags}
    elif el.tag == 'way':
        way_attribs = {f: el.attrib[f] for f in way_attr_fields}
        way_nodes = [shape_way_node(el, i, nd)
                     for i, nd
                     in enumerate(el.iter('nd'))]
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}
    
def get_element(osm_file, tags = ('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""
    context = ET.iterparse(osm_file, events=("start", "end"))
    _, root = next(context)
    for event, elem in context:
        if event == "end" and elem.tag in tags:
            yield elem
            root.clear()
            
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""
    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k:(v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })
        
    def writerows(self, rows):
        for row in rows:
            self.writerow(row)
            
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""    
    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:
                
        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)
        
        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()
        
        for element in get_element(file_in, tags = ('node', 'way')):
            el = shape_element(element)
            if el:
                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

if __name__ == '__main__':
    process_map(OSM_PATH, validate = False)
